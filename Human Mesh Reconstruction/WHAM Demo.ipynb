# %%
# !git clone https://github.com/yohanshin/WHAM/ --recursive
# Out:
# fatal: destination path 'WHAM' already exists and is not an empty directory.

# %%
# Install conda

# !pip install -q condacolab
from shutil import which
import condacolab
if which("conda") is None:
  condacolab.install()

# %%
# !conda create -n wham python=3.9
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/wham
#
#   added / updated specs:
#     - python=3.9
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      conda-forge/linux-64::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-2_gnu
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h4bc722e_7
#   ca-certificates    conda-forge/linux-64::ca-certificates-2024.7.4-hbcca054_0
#   ld_impl_linux-64   conda-forge/linux-64::ld_impl_linux-64-2.40-hf3520f5_7
#   libffi             conda-forge/linux-64::libffi-3.4.2-h7f98852_5
#   libgcc-ng          conda-forge/linux-64::libgcc-ng-14.1.0-h77fa898_0
# ...

# %%
# Install dependencies

# %cd /content/WHAM
# PyTorch
# !source activate wham && conda install pytorch==1.11.0 torchvision==0.12.0 torchaudio==0.11.0 cudatoolkit=11.3 -c pytorch

# PyTorch 3D
# !source activate wham && conda install -c fvcore -c iopath -c conda-forge fvcore iopath
# !source activate wham && pip install pytorch3d -f https://dl.fbaipublicfiles.com/pytorch3d/packaging/wheels/py39_cu113_pyt1110/download.html

# Dependencies
# !source activate wham && pip install -r requirements.txt
# Out:
# /content/WHAM
# Channels:
#  - pytorch
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/wham
#
#   added / updated specs:
#     - cudatoolkit=11.3
#     - pytorch==1.11.0
#     - torchaudio==0.11.0
#     - torchvision==0.12.0
#
#
# The following NEW packages will be INSTALLED:
#
#   aom                conda-forge/linux-64::aom-3.5.0-h27087fc_0
#   blas               conda-forge/linux-64::blas-2.123-mkl
#   blas-devel         conda-forge/linux-64::blas-devel-3.9.0-23_linux64_mkl
#   brotli-python      conda-forge/linux-64::brotli-python-1.1.0-py39h3d6467e_1
#   cairo              conda-forge/linux-64::cairo-1.16.0-h35add3b_1015
#   certifi            conda-forge/noarch::certifi-2024.7.4-pyhd8ed1ab_0
# ...

# %%
# !source activate wham && pip install -v -e third-party/ViTPose
# Out:
# Using pip 24.0 from /usr/local/envs/wham/lib/python3.9/site-packages/pip (python 3.9)
# Obtaining file:///content/WHAM/third-party/ViTPose
#   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-ndbc3ctu/mmpose.egg-info
#   writing /tmp/pip-pip-egg-info-ndbc3ctu/mmpose.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-ndbc3ctu/mmpose.egg-info/dependency_links.txt
#   writing requirements to /tmp/pip-pip-egg-info-ndbc3ctu/mmpose.egg-info/requires.txt
#   writing top-level names to /tmp/pip-pip-egg-info-ndbc3ctu/mmpose.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-ndbc3ctu/mmpose.egg-info/SOURCES.txt'
#   reading manifest file '/tmp/pip-pip-egg-info-ndbc3ctu/mmpose.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   adding license file 'LICENSE'
#   writing manifest file '/tmp/pip-pip-egg-info-ndbc3ctu/mmpose.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
# ...

# %%
# %cd /content/WHAM/third-party/DPVO
# !wget https://gitlab.com/libeigen/eigen/-/archive/3.4.0/eigen-3.4.0.zip
# !unzip eigen-3.4.0.zip -d thirdparty && rm -rf eigen-3.4.0.zip
# !source activate wham && conda install pytorch-scatter=2.0.9 -c rusty1s
# !source activate wham && conda install cudatoolkit-dev=11.3.1 -c conda-forge
# !source activate wham && conda install -c conda-forge gxx=9.5   # Only if GCC version is greater than 10.
# Out:
# /content/WHAM/third-party/DPVO
# --2024-07-25 21:01:04--  https://gitlab.com/libeigen/eigen/-/archive/3.4.0/eigen-3.4.0.zip
# Resolving gitlab.com (gitlab.com)... 172.65.251.78, 2606:4700:90:0:f22e:fbec:5bed:a9b9
# Connecting to gitlab.com (gitlab.com)|172.65.251.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘eigen-3.4.0.zip’
#
# eigen-3.4.0.zip         [ <=>                ]   3.53M  --.-KB/s    in 0.06s
#
# 2024-07-25 21:01:04 (56.1 MB/s) - ‘eigen-3.4.0.zip’ saved [3700486]
#
# Archive:  eigen-3.4.0.zip
# 3147391d946bb4b6c68edd901f2add6ac1f31f8c
#    creating: thirdparty/eigen-3.4.0/
#   inflating: thirdparty/eigen-3.4.0/.gitignore
#   inflating: thirdparty/eigen-3.4.0/.gitlab-ci.yml
#    creating: thirdparty/eigen-3.4.0/.gitlab/
#    creating: thirdparty/eigen-3.4.0/.gitlab/issue_templates/
#   inflating: thirdparty/eigen-3.4.0/.gitlab/issue_templates/Bug Report.md
# ...

# %%
# !git clone --recursive https://github.com/princeton-vl/DPVO
# %cd /content/DPVO
# !wget https://gitlab.com/libeigen/eigen/-/archive/3.4.0/eigen-3.4.0.zip
# !unzip eigen-3.4.0.zip -d thirdparty
# !conda install -c conda-forge poppler # for visualization
# !pip install open3d evo pdf2image # for visualization
# Out:
# Cloning into 'DPVO'...
# remote: Enumerating objects: 289, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 289 (delta 23), reused 22 (delta 14), pack-reused 234
# Receiving objects: 100% (289/289), 1.82 MiB | 16.46 MiB/s, done.
# Resolving deltas: 100% (34/34), done.
# Submodule 'Pangolin' (https://github.com/zachteed/Pangolin.git) registered for path 'Pangolin'
# Cloning into '/content/DPVO/Pangolin'...
# remote: Enumerating objects: 18911, done.
# remote: Total 18911 (delta 0), reused 0 (delta 0), pack-reused 18911
# Receiving objects: 100% (18911/18911), 33.48 MiB | 28.22 MiB/s, done.
# Resolving deltas: 100% (12595/12595), done.
# Submodule path 'Pangolin': checked out '93712f0666003f392ac8414bc2c0a009081e91c1'
# Submodule 'components/pango_python/pybind11' (https://github.com/pybind/pybind11.git) registered for path 'Pangolin/components/pango_python/pybind11'
# ...

# %%
# %cd /content/DPVO
# !source activate wham && conda env update -f environment.yml
# Out:
# /content/DPVO
# Channels:
#  - pyg
#  - pytorch
#  - conda-forge
#  - defaults
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ...
# pytorch-1.12.0       | 1.19 GB   | :   0% 0/1 [00:00<?, ?it/s]
# cudatoolkit-11.3.1   | 549.3 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
# mkl-2021.4.0         | 142.6 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
# qt-5.9.7             | 68.5 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# scipy-1.7.3          | 43.6 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# torchvision-0.13.0   | 28.3 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# grpcio-1.42.0        | 24.3 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# python-3.10.0        | 23.5 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# numpy-base-1.22.3    | 11.8 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# ...

# %%
# %cd /content/DPVO
# !source activate wham && \
conda install ipykernel -y && \
conda install -c "nvidia/label/cuda-11.7.0" cuda-toolkit && \
conda install -c "nvidia/label/cuda-11.7.0" cuda && \
pip install .

# %%
# Out:
# /content/WHAM

# %%
# Enter your usernames and passwords for SMPL and SMPLify pages below.
# %cd /content/WHAM
# !source activate wham && bash fetch_demo_data.sh
# Out:
# You need to register at https://smplify.is.tue.mpg.de
# Username (SMPLify):^C

# %%
# !python demo.py --video examples/IMG_9732.mov --visualize

# %%
# !python demo.py --video examples/IMG_9732.mov --visualize --estimate_local_only

# %%
# !source activate wham && python demo.py --video examples/drone_video.mp4 --calib examples/drone_calib.txt --visualize
