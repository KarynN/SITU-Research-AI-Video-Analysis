# %% [markdown]
# # Scrape NYPD officer profile images from 50-a.org

# %%
import requests
from bs4 import BeautifulSoup
import re
import os
import json

# %%
#get all individual officer page links
def get_links_from_website(url):
    try:
        response = requests.get(url)
        response.raise_for_status()

        soup = BeautifulSoup(response.text, 'html.parser')

        anchor_tags = soup.find_all('a')

        links = [tag.get('href') for tag in anchor_tags if tag.get('href')]

        return links
    except requests.exceptions.RequestException as e:
        print(f"Error fetching {url}: {e}")
        return []

url = 'https://www.50-a.org/commands'
links = get_links_from_website(url)
links_list = list(links)
links_list = links_list[1:-3]

# %%
def download_images(data, base_url):
    if not os.path.exists('faces2'):
        os.makedirs('faces2')

    for entry in data:
        if entry['source_link']:
            # Create full URL to cop page
            full_url = base_url + entry['source_link']

            badge_number = entry['badge_number'][1:] if entry['badge_number'] else 'unknown'
            allegations = entry['allegations'] if entry['allegations'] else 'unknown'
            name = entry['source_link']
            file_name = name#f"{badge_number}_{allegations}_{name}.jpg"

            try:
                img_data = requests.get(full_url).content
                with open(os.path.join('faces2', file_name), 'wb') as handler:
                    handler.write(img_data)
                print(f"Downloaded {file_name}")
            except requests.exceptions.RequestException as e:
                print(f"Error downloading {full_url}: {e}")

# %%
#scrape basic officer data from link
def scrape_website2(url):
    try:
        # Send a GET request to the website
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')

        table = soup.find('table')
        table_rows = table.find_all('tr')

        rows = []
        for tr in table_rows:
            # Extract text content of the entire row
            row_text = ' '.join(td.text.strip() for td in tr.find_all(['td']))
            # Extract the <a> link within the <td class="photo">, if it exists
            photo_td = tr.find(['td'], class_='photo')

            source_tag = photo_td.find('img') if photo_td else None
            source_link = source_tag.get('src') if source_tag else None
            source_link = source_link.split('/')[-1] if source_tag else None

            parts = row_text.split('\n')
            name = parts[0].strip() if len(parts) > 0 else None

            rest = parts[1].strip() if len(parts) > 1 else ''
            rest_parts = rest.split()
            badge_number = rest_parts[0] if len(rest_parts) > 0 else None
            allegations = rest_parts[1] if len(rest_parts) > 1 else None

            rows.append({'name': name, 'badge_number': badge_number, 'allegations': allegations, 'source_link': source_link})

        return rows

    except requests.exceptions.RequestException as e:
        print(f"Error fetching {url}: {e}")
        return {}

# %%
#test on police profile url
url = 'https://www.50-a.org/command/1pct?image=on'
scraped_data = scrape_website2(url)

# %%
scraped_data[1]
# Out:
# {'name': 'Gut, Frank J.',
#  'badge_number': '#5662',
#  'allegations': '7',
#  'source_link': '47B7-frank-gut.jpg'}

# %%
#process all police profile pages
import json
def process_links(urls):
    all_data = []
    for url in urls:
        commandurl = "https://www.50-a.org" + url + "?image=on"
        print(f"Processing {commandurl}")
        data = scrape_website2(commandurl)
        all_data.extend(data)
        imgurl = "https://www.50-a.org/images/officer/"
        download_images(data, imgurl)

    # Save all data to a single JSON file
    with open('nypd.json', 'w') as json_file:
        json.dump(all_data, json_file, indent=4)

# %%
process_links(links_list)
# Out:
# Streaming output truncated to the last 5000 lines.
# Downloaded UKPP-christopher-wilson.jpg
# Downloaded WE6X-dennis-burgos.jpg
# Downloaded GEET-mark-sinatra.jpg
# Downloaded EH5U-robert-zajac.jpg
# Downloaded YH97-matthew-granahan.jpg
# Downloaded E9NT-jesse-dray.jpg
# Downloaded V7VX-michele-stewart.jpg
# Downloaded 8WRR-daniel-magee.jpg
# Downloaded E7BT-avion-esposito.jpg
# Downloaded UJPT-mostafa-bennejima.jpg
# Downloaded BPFK-gabriel-alvarez.jpg
# Downloaded TESF-sajjad-baloch.jpg
# Downloaded LRUZ-edwin-cardona.jpg
# Downloaded QUCB-james-carlo.jpg
# Downloaded 7D6V-raymond-chan.jpg
# Downloaded 9TDP-malcolm-mckenzie.jpg
# Downloaded 7XJ3-keith-moynihan.jpg
# Downloaded A2BV-cagney-ramos.jpg
# Downloaded XKAF-renee-vidiksis.jpg
# Downloaded BB2D-andrew-washack.jpg
# Downloaded SB57-daniel-weglarz.jpg
# Processing https://www.50-a.org/command/471?image=on
# Downloaded TXP-marcello-massafra.jpg
# Downloaded GT87-francisco-aviles.jpg
# Downloaded V2ZP-aleksandr-vygon.jpg
# Downloaded 9JV7-tanya-barry.jpg
# Downloaded 4LGR-roger-bennett.jpg
# Downloaded FXUK-ryon-malcolm.jpg
# Downloaded D3SX-nakisha-bogle.jpg
# Downloaded XUVB-tayka-bois.jpg
# Downloaded CJ8F-keynayia-gorman.jpg
# Downloaded T76D-samantha-williams.jpg
# Downloaded 48YM-krystal-small.jpg
# Downloaded RHJ5-clinton-wike.jpg
# Downloaded REQ5-jenny-garcia.jpg
# Downloaded AKHV-eduard-bilenkis.jpg
# Downloaded FXS3-johnny-hines.jpg
# Downloaded X9X-alberto-valentin.jpg
# Downloaded U4UD-joseph-cutler.jpg
# Downloaded GFSK-jesus-santos.jpg
# Downloaded DTT3-jackeline-bodden.jpg
# Downloaded X3UP-sonia-belardo.jpg
# Downloaded 5HLB-thurman-ransom.jpg
# Downloaded LZDX-frankie-iglesias.jpg
# Downloaded KNJD-adrian-mendes.jpg
# Downloaded QC25-sharisse-sanders.jpg
# Downloaded R6VH-sabrina-kennedy.jpg
# Downloaded HQSR-howard-dy.jpg
# Downloaded KNEM-dironda-rodriques.jpg
# Downloaded 76D-makiah-brown.jpg
# Downloaded UNB5-latoya-crooks.jpg
# Downloaded HSKM-almira-dzaferovic.jpg
# Downloaded BB6F-richard-fernandez.jpg
# Downloaded 6HFD-anthony-gomez.jpg
# Downloaded YB25-melissa-hobbs.jpg
# Downloaded 5RZ3-janel-howard.jpg
# Downloaded GJCF-kemel-johnson.jpg
# Downloaded TL5Z-terrence-kinslow.jpg
# Downloaded G28H-jelani-obafemi.jpg
# Downloaded GZDP-anthony-rivera.jpg
# Downloaded YEFH-yvette-saintaubin.jpg
# Downloaded L9GX-vicken-tajian.jpg
# Downloaded K8RR-aja-white.jpg

# %%
scraped_data[1]
# Out:
# {'name': 'Gut, Frank J.',
#  'badge_number': '#5662',
#  'allegations': '7',
#  'source_link': '/images/officer/384/47B7-frank-gut.avif'}

# %% [markdown]
# # Embed Profile Images with InsightFace

# %%
app = FaceAnalysis(name='antelopev2', root='./', providers=['CUDAExecutionProvider', 'CPUExecutionProvider'])
app.prepare(ctx_id=0, det_size=(128, 128))

def generate_embedding(imgpath):
    img = np.array(Image.open(imgpath))[:,:,::-1]
    faces = app.get(img)
    if faces:
        id_emb = torch.tensor(faces[0]['embedding'], dtype=torch.float32)[None].cuda()
        id_emb = id_emb / torch.norm(id_emb, dim=1, keepdim=True)
        id_emb = id_emb.cpu()
        return id_emb
    return None
# Out:
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'use_tf32': '1', 'prefer_nhwc': '0', 'tunable_op_max_tuning_duration_ms': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_tuning_enable': '0', 'tunable_op_enable': '0', 'use_ep_level_unified_stream': '0', 'device_id': '0', 'has_user_compute_stream': '0', 'gpu_external_empty_cache': '0', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_alloc': '0', 'gpu_external_free': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'do_copy_in_default_stream': '1', 'enable_cuda_graph': '0', 'user_compute_stream': '0', 'cudnn_conv_use_max_workspace': '1'}}
# find model: ./models/antelopev2/1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'use_tf32': '1', 'prefer_nhwc': '0', 'tunable_op_max_tuning_duration_ms': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_tuning_enable': '0', 'tunable_op_enable': '0', 'use_ep_level_unified_stream': '0', 'device_id': '0', 'has_user_compute_stream': '0', 'gpu_external_empty_cache': '0', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_alloc': '0', 'gpu_external_free': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'do_copy_in_default_stream': '1', 'enable_cuda_graph': '0', 'user_compute_stream': '0', 'cudnn_conv_use_max_workspace': '1'}}
# find model: ./models/antelopev2/2d106det.onnx landmark_2d_106 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'use_tf32': '1', 'prefer_nhwc': '0', 'tunable_op_max_tuning_duration_ms': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_tuning_enable': '0', 'tunable_op_enable': '0', 'use_ep_level_unified_stream': '0', 'device_id': '0', 'has_user_compute_stream': '0', 'gpu_external_empty_cache': '0', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_alloc': '0', 'gpu_external_free': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'do_copy_in_default_stream': '1', 'enable_cuda_graph': '0', 'user_compute_stream': '0', 'cudnn_conv_use_max_workspace': '1'}}
# find model: ./models/antelopev2/arcface.onnx recognition ['None', 3, 112, 112] 127.5 127.5
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'use_tf32': '1', 'prefer_nhwc': '0', 'tunable_op_max_tuning_duration_ms': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_tuning_enable': '0', 'tunable_op_enable': '0', 'use_ep_level_unified_stream': '0', 'device_id': '0', 'has_user_compute_stream': '0', 'gpu_external_empty_cache': '0', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_alloc': '0', 'gpu_external_free': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'do_copy_in_default_stream': '1', 'enable_cuda_graph': '0', 'user_compute_stream': '0', 'cudnn_conv_use_max_workspace': '1'}}
# find model: ./models/antelopev2/genderage.onnx genderage ['None', 3, 96, 96] 0.0 1.0
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'use_tf32': '1', 'prefer_nhwc': '0', 'tunable_op_max_tuning_duration_ms': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_tuning_enable': '0', 'tunable_op_enable': '0', 'use_ep_level_unified_stream': '0', 'device_id': '0', 'has_user_compute_stream': '0', 'gpu_external_empty_cache': '0', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_alloc': '0', 'gpu_external_free': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'do_copy_in_default_stream': '1', 'enable_cuda_graph': '0', 'user_compute_stream': '0', 'cudnn_conv_use_max_workspace': '1'}}
# find model: ./models/antelopev2/scrfd_10g_bnkps.onnx detection [1, 3, '?', '?'] 127.5 128.0
# set det-size: (128, 128)

# %%
def process_images_in_folder(folder_path, checkpoint_dir):
    embeddings = []
    image_names = []
    checkpoint_interval = 10
    checkpoint_path = os.path.join(checkpoint_dir, 'embeddings_checkpoint.pkl')

    os.makedirs(checkpoint_dir, exist_ok=True)

    # Load checkpoint if it exists
    if os.path.exists(checkpoint_path):
        with open(checkpoint_path, 'rb') as f:
            image_names, embeddings = pickle.load(f)
        print(f"Checkpoint loaded. Resuming from {len(image_names)} images.")

    all_image_files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

    # Filter out images that are already processed
    processed_images = set(image_names)
    image_files = [f for f in all_image_files if f not in processed_images]

    # Process images with progress
    for i, image_file in enumerate(tqdm(image_files, desc="Processing images", initial=len(processed_images), total=len(all_image_files))):
        imgpath = os.path.join(folder_path, image_file)
        embedding = generate_embedding(imgpath)
        if embedding is not None:
            embeddings.append(embedding.numpy())
            image_names.append(image_file)

        # Save checkpoint every checkpoint_interval embeddings
        if (len(image_names)) % checkpoint_interval == 0:
            with open(checkpoint_path, 'wb') as f:
                pickle.dump((image_names, embeddings), f)
            print(f"Checkpoint saved after {len(image_names)} images")

    # Save final embeddings
    final_path = os.path.join(checkpoint_dir, 'embeddings_final.pkl')
    with open(final_path, 'wb') as f:
        pickle.dump((image_names, embeddings), f)
    print("Final embeddings saved")

folder_path = '/content/drive/MyDrive/faces/NYPD_profile_imgs'
checkpoint_dir = '/content/drive/MyDrive/faces/emb_checkpoints'
process_images_in_folder(folder_path, checkpoint_dir)
# Out:
# Processing images:   0%|          | 0/11607 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/insightface/utils/transform.py:68: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   P = np.linalg.lstsq(X_homo, Y)[0].T # Affine matrix. 3 x 4
# Checkpoint saved after 10 images
# Checkpoint saved after 20 images
# Checkpoint saved after 30 images
# Checkpoint saved after 40 images
# Checkpoint saved after 50 images
# Checkpoint saved after 60 images
# Checkpoint saved after 70 images
# Checkpoint saved after 80 images
# Checkpoint saved after 90 images
# Checkpoint saved after 100 images
# Checkpoint saved after 110 images
# Checkpoint saved after 120 images
# Checkpoint saved after 130 images
# Checkpoint saved after 140 images
# Checkpoint saved after 150 images
# Checkpoint saved after 160 images
# Checkpoint saved after 170 images
# Checkpoint saved after 180 images
# Checkpoint saved after 190 images
# Checkpoint saved after 200 images
# Checkpoint saved after 210 images
# Checkpoint saved after 220 images
# Checkpoint saved after 230 images
# Checkpoint saved after 240 images
# Checkpoint saved after 250 images
# Checkpoint saved after 260 images
# Checkpoint saved after 270 images
# Checkpoint saved after 280 images
# Checkpoint saved after 290 images
# Checkpoint saved after 300 images
# Checkpoint saved after 310 images
# Checkpoint saved after 320 images
# Checkpoint saved after 330 images
# Checkpoint saved after 340 images
# Checkpoint saved after 350 images
# Checkpoint saved after 360 images
# Checkpoint saved after 370 images
# Checkpoint saved after 380 images
# Checkpoint saved after 390 images
# Checkpoint saved after 400 images
# Checkpoint saved after 410 images
# Checkpoint saved after 420 images
# Checkpoint saved after 430 images
# Checkpoint saved after 440 images
# Checkpoint saved after 450 images
# Checkpoint saved after 460 images
# Checkpoint saved after 470 images
# Checkpoint saved after 480 images
# Checkpoint saved after 490 images
# Checkpoint saved after 500 images
# Checkpoint saved after 510 images
# Checkpoint saved after 520 images
# Checkpoint saved after 530 images
# Checkpoint saved after 540 images
# Checkpoint saved after 550 images
# Checkpoint saved after 560 images
# Checkpoint saved after 570 images
# Checkpoint saved after 580 images
# Checkpoint saved after 590 images
# Checkpoint saved after 600 images
# Checkpoint saved after 610 images
# Checkpoint saved after 620 images
# Checkpoint saved after 630 images
# Checkpoint saved after 640 images
# Checkpoint saved after 650 images
# Checkpoint saved after 660 images
# Checkpoint saved after 670 images
# Checkpoint saved after 680 images
# Checkpoint saved after 690 images
# Checkpoint saved after 700 images
# Checkpoint saved after 710 images
# Checkpoint saved after 720 images
# Checkpoint saved after 730 images
# Checkpoint saved after 740 images
# Checkpoint saved after 750 images
# Checkpoint saved after 760 images
# Checkpoint saved after 770 images
# Checkpoint saved after 780 images
# Checkpoint saved after 790 images
# Checkpoint saved after 800 images
# Checkpoint saved after 810 images
# Checkpoint saved after 820 images
# Checkpoint saved after 830 images
# Checkpoint saved after 840 images
# Checkpoint saved after 850 images
# Checkpoint saved after 860 images
# Checkpoint saved after 870 images
# Checkpoint saved after 880 images
# Checkpoint saved after 890 images
# Checkpoint saved after 900 images
# Checkpoint saved after 910 images
# Checkpoint saved after 920 images
# Checkpoint saved after 930 images
# Checkpoint saved after 940 images
# Checkpoint saved after 950 images
# Checkpoint saved after 960 images
# Checkpoint saved after 970 images
# Checkpoint saved after 980 images
# Checkpoint saved after 990 images
# Checkpoint saved after 1000 images
# Checkpoint saved after 1010 images
# Checkpoint saved after 1020 images
# Checkpoint saved after 1030 images
# Checkpoint saved after 1040 images
# Checkpoint saved after 1050 images
# Checkpoint saved after 1060 images
# Checkpoint saved after 1070 images
# Checkpoint saved after 1080 images
# Checkpoint saved after 1090 images
# Checkpoint saved after 1100 images
# Checkpoint saved after 1110 images
# Checkpoint saved after 1120 images
# Checkpoint saved after 1130 images
# Checkpoint saved after 1140 images
# Checkpoint saved after 1150 images
# Checkpoint saved after 1160 images
# Checkpoint saved after 1170 images
# Checkpoint saved after 1180 images
# Checkpoint saved after 1190 images
# Checkpoint saved after 1200 images
# Checkpoint saved after 1210 images
# Checkpoint saved after 1220 images
# Checkpoint saved after 1230 images
# Checkpoint saved after 1240 images
# Checkpoint saved after 1250 images
# Checkpoint saved after 1260 images
# Checkpoint saved after 1270 images
# Checkpoint saved after 1280 images
# Checkpoint saved after 1290 images
# Checkpoint saved after 1300 images
# Checkpoint saved after 1310 images
# Checkpoint saved after 1320 images
# Checkpoint saved after 1330 images
# Checkpoint saved after 1340 images
# Checkpoint saved after 1350 images
# Checkpoint saved after 1360 images
# Checkpoint saved after 1370 images
# Checkpoint saved after 1380 images
# Checkpoint saved after 1390 images
# Checkpoint saved after 1400 images
# Checkpoint saved after 1410 images
# Checkpoint saved after 1420 images
# Checkpoint saved after 1430 images
# Checkpoint saved after 1440 images
# Checkpoint saved after 1450 images
# Checkpoint saved after 1460 images
# Checkpoint saved after 1470 images
# Checkpoint saved after 1480 images
# Checkpoint saved after 1490 images
# Checkpoint saved after 1500 images
# Checkpoint saved after 1510 images
# Checkpoint saved after 1520 images
# Checkpoint saved after 1530 images
# Checkpoint saved after 1540 images
# Checkpoint saved after 1550 images
# Checkpoint saved after 1560 images
# Checkpoint saved after 1570 images
# Checkpoint saved after 1580 images
# Checkpoint saved after 1590 images
# Checkpoint saved after 1600 images
# Checkpoint saved after 1610 images
# Checkpoint saved after 1620 images
# Checkpoint saved after 1630 images
# Checkpoint saved after 1640 images
# Checkpoint saved after 1650 images
# Checkpoint saved after 1660 images
# Checkpoint saved after 1670 images
# Checkpoint saved after 1680 images
# Checkpoint saved after 1690 images
# Checkpoint saved after 1690 images
# Checkpoint saved after 1700 images
# Checkpoint saved after 1710 images
# Checkpoint saved after 1720 images
# Checkpoint saved after 1730 images
# Checkpoint saved after 1740 images
# Checkpoint saved after 1750 images
# Checkpoint saved after 1760 images
# Checkpoint saved after 1770 images
# Checkpoint saved after 1780 images
# Checkpoint saved after 1790 images
# Checkpoint saved after 1800 images
# Checkpoint saved after 1810 images
# Checkpoint saved after 1820 images
# Checkpoint saved after 1830 images
# Checkpoint saved after 1840 images
# Checkpoint saved after 1850 images
# Checkpoint saved after 1860 images
# Checkpoint saved after 1870 images
# Checkpoint saved after 1880 images
# Checkpoint saved after 1890 images
# Checkpoint saved after 1900 images
# Checkpoint saved after 1910 images
# Checkpoint saved after 1920 images
# Checkpoint saved after 1930 images
# Checkpoint saved after 1940 images
# Checkpoint saved after 1950 images
# Checkpoint saved after 1960 images
# Checkpoint saved after 1970 images
# Checkpoint saved after 1980 images
# Checkpoint saved after 1990 images
# Checkpoint saved after 2000 images
# Checkpoint saved after 2010 images
# Checkpoint saved after 2020 images
# Checkpoint saved after 2030 images
# Checkpoint saved after 2040 images
# Checkpoint saved after 2050 images
# Checkpoint saved after 2060 images
# Checkpoint saved after 2070 images
# Checkpoint saved after 2080 images
# Checkpoint saved after 2090 images
# Checkpoint saved after 2100 images
# Checkpoint saved after 2110 images
# Checkpoint saved after 2120 images
# Checkpoint saved after 2130 images
# Checkpoint saved after 2140 images
# Checkpoint saved after 2150 images
# Checkpoint saved after 2160 images
# Checkpoint saved after 2170 images
# Checkpoint saved after 2180 images
# Checkpoint saved after 2190 images
# Checkpoint saved after 2200 images
# Checkpoint saved after 2210 images
# Checkpoint saved after 2220 images
# Checkpoint saved after 2230 images
# Checkpoint saved after 2240 images
# Checkpoint saved after 2250 images
# Checkpoint saved after 2260 images
# Checkpoint saved after 2270 images
# Checkpoint saved after 2280 images
# Checkpoint saved after 2290 images
# Checkpoint saved after 2300 images
# Checkpoint saved after 2310 images
# Checkpoint saved after 2320 images
# Checkpoint saved after 2330 images
# Checkpoint saved after 2340 images
# Checkpoint saved after 2350 images
# Checkpoint saved after 2360 images
# Checkpoint saved after 2370 images
# Checkpoint saved after 2380 images
# Checkpoint saved after 2390 images
# Checkpoint saved after 2400 images
# Checkpoint saved after 2410 images
# Checkpoint saved after 2420 images
# Checkpoint saved after 2430 images
# Checkpoint saved after 2440 images
# Checkpoint saved after 2450 images
# Checkpoint saved after 2460 images
# Checkpoint saved after 2470 images
# Checkpoint saved after 2480 images
# Checkpoint saved after 2490 images
# Checkpoint saved after 2500 images
# Checkpoint saved after 2510 images
# Checkpoint saved after 2520 images
# Checkpoint saved after 2530 images
# Checkpoint saved after 2540 images
# Checkpoint saved after 2550 images
# Checkpoint saved after 2560 images
# Checkpoint saved after 2570 images
# Checkpoint saved after 2580 images
# Checkpoint saved after 2590 images
# Checkpoint saved after 2600 images
# Checkpoint saved after 2610 images
# Checkpoint saved after 2620 images
# Checkpoint saved after 2630 images
# Checkpoint saved after 2640 images
# Checkpoint saved after 2650 images
# Checkpoint saved after 2660 images
# Checkpoint saved after 2670 images
# Checkpoint saved after 2680 images
# Checkpoint saved after 2690 images
# Checkpoint saved after 2700 images
# Checkpoint saved after 2710 images
# Checkpoint saved after 2720 images
# Checkpoint saved after 2730 images
# Checkpoint saved after 2740 images
# Checkpoint saved after 2750 images
# Checkpoint saved after 2760 images
# Checkpoint saved after 2770 images
# Checkpoint saved after 2780 images
# Checkpoint saved after 2790 images
# Checkpoint saved after 2800 images
# Checkpoint saved after 2810 images
# Checkpoint saved after 2820 images
# Checkpoint saved after 2830 images
# Checkpoint saved after 2840 images
# Checkpoint saved after 2850 images
# Checkpoint saved after 2860 images
# Checkpoint saved after 2870 images
# Checkpoint saved after 2880 images
# Checkpoint saved after 2890 images
# Checkpoint saved after 2900 images
# Checkpoint saved after 2910 images
# Checkpoint saved after 2920 images
# Checkpoint saved after 2930 images
# Checkpoint saved after 2940 images
# Checkpoint saved after 2950 images
# Checkpoint saved after 2960 images
# Checkpoint saved after 2970 images
# Checkpoint saved after 2980 images
# Checkpoint saved after 2990 images
# Checkpoint saved after 3000 images
# Checkpoint saved after 3010 images
# Checkpoint saved after 3020 images
# Checkpoint saved after 3030 images
# Checkpoint saved after 3040 images
# Checkpoint saved after 3050 images
# Checkpoint saved after 3060 images
# Checkpoint saved after 3070 images
# Checkpoint saved after 3080 images
# Checkpoint saved after 3090 images
# Checkpoint saved after 3100 images
# Checkpoint saved after 3110 images
# Checkpoint saved after 3120 images
# Checkpoint saved after 3130 images
# Checkpoint saved after 3140 images
# Checkpoint saved after 3150 images
# Checkpoint saved after 3160 images
# Checkpoint saved after 3170 images
# Checkpoint saved after 3180 images
# Checkpoint saved after 3190 images
# Checkpoint saved after 3200 images
# Checkpoint saved after 3210 images
# Checkpoint saved after 3220 images
# Checkpoint saved after 3230 images
# Checkpoint saved after 3240 images
# Checkpoint saved after 3250 images
# Checkpoint saved after 3260 images
# Checkpoint saved after 3270 images
# Checkpoint saved after 3280 images
# Checkpoint saved after 3290 images
# Checkpoint saved after 3300 images
# Checkpoint saved after 3310 images
# Checkpoint saved after 3320 images
# Checkpoint saved after 3330 images
# Checkpoint saved after 3340 images
# Checkpoint saved after 3350 images
# Checkpoint saved after 3360 images
# Checkpoint saved after 3370 images
# Checkpoint saved after 3380 images
# Checkpoint saved after 3390 images
# Checkpoint saved after 3400 images
# Checkpoint saved after 3410 images
# Checkpoint saved after 3420 images
# Checkpoint saved after 3430 images
# Checkpoint saved after 3440 images
# Checkpoint saved after 3450 images
# Checkpoint saved after 3450 images
# Checkpoint saved after 3460 images
# Checkpoint saved after 3470 images
# Checkpoint saved after 3480 images
# Checkpoint saved after 3490 images
# Checkpoint saved after 3500 images
# Checkpoint saved after 3510 images
# Checkpoint saved after 3520 images
# Checkpoint saved after 3530 images
# Checkpoint saved after 3540 images
# Checkpoint saved after 3550 images
# Checkpoint saved after 3560 images
# Checkpoint saved after 3570 images
# Checkpoint saved after 3580 images
# Checkpoint saved after 3590 images
# Checkpoint saved after 3600 images
# Checkpoint saved after 3610 images
# Checkpoint saved after 3620 images
# Checkpoint saved after 3630 images
# Checkpoint saved after 3640 images
# Checkpoint saved after 3650 images
# Checkpoint saved after 3660 images
# Checkpoint saved after 3670 images
# Checkpoint saved after 3680 images
# Checkpoint saved after 3690 images
# Checkpoint saved after 3700 images
# Checkpoint saved after 3710 images
# Checkpoint saved after 3720 images
# Checkpoint saved after 3730 images
# Checkpoint saved after 3740 images
# Checkpoint saved after 3750 images
# Checkpoint saved after 3760 images
# Checkpoint saved after 3770 images
# Checkpoint saved after 3780 images
# Checkpoint saved after 3790 images
# Checkpoint saved after 3800 images
# Checkpoint saved after 3810 images
# Checkpoint saved after 3820 images
# Checkpoint saved after 3830 images
# Checkpoint saved after 3840 images
# Checkpoint saved after 3850 images
# Checkpoint saved after 3860 images
# Checkpoint saved after 3870 images
# Checkpoint saved after 3880 images
# Checkpoint saved after 3890 images
# Checkpoint saved after 3900 images
# Checkpoint saved after 3910 images
# Checkpoint saved after 3920 images
# Checkpoint saved after 3930 images
# Checkpoint saved after 3940 images
# Checkpoint saved after 3950 images
# Checkpoint saved after 3960 images
# Checkpoint saved after 3970 images
# Checkpoint saved after 3980 images
# Checkpoint saved after 3990 images
# Checkpoint saved after 4000 images
# Checkpoint saved after 4010 images
# Checkpoint saved after 4020 images
# Checkpoint saved after 4030 images
# Checkpoint saved after 4040 images
# Checkpoint saved after 4050 images
# Checkpoint saved after 4060 images
# Checkpoint saved after 4070 images
# Checkpoint saved after 4080 images
# Checkpoint saved after 4090 images
# Checkpoint saved after 4100 images
# Checkpoint saved after 4110 images
# Checkpoint saved after 4120 images
# Checkpoint saved after 4130 images
# Checkpoint saved after 4140 images
# Checkpoint saved after 4150 images
# Checkpoint saved after 4160 images
# Checkpoint saved after 4170 images
# Checkpoint saved after 4180 images
# Checkpoint saved after 4190 images
# Checkpoint saved after 4200 images
# Checkpoint saved after 4210 images
# Checkpoint saved after 4220 images
# Checkpoint saved after 4230 images
# Checkpoint saved after 4240 images
# Checkpoint saved after 4250 images
# Checkpoint saved after 4260 images
# Checkpoint saved after 4270 images
# Checkpoint saved after 4280 images
# Checkpoint saved after 4290 images
# Checkpoint saved after 4300 images
# Checkpoint saved after 4310 images
# Checkpoint saved after 4320 images
# Checkpoint saved after 4330 images
# Checkpoint saved after 4340 images
# Checkpoint saved after 4350 images
# Checkpoint saved after 4360 images
# Checkpoint saved after 4370 images
# Checkpoint saved after 4380 images
# Checkpoint saved after 4390 images
# Checkpoint saved after 4400 images
# Checkpoint saved after 4410 images
# Checkpoint saved after 4420 images
# Checkpoint saved after 4430 images
# Checkpoint saved after 4440 images
# Checkpoint saved after 4450 images
# Checkpoint saved after 4460 images
# Checkpoint saved after 4470 images
# Checkpoint saved after 4480 images
# Checkpoint saved after 4490 images
# Checkpoint saved after 4500 images
# Checkpoint saved after 4510 images
# Checkpoint saved after 4520 images
# Checkpoint saved after 4530 images
# Checkpoint saved after 4540 images
# Checkpoint saved after 4550 images
# Checkpoint saved after 4560 images
# Checkpoint saved after 4570 images
# Checkpoint saved after 4580 images
# Checkpoint saved after 4590 images
# Checkpoint saved after 4600 images
# Checkpoint saved after 4610 images
# Checkpoint saved after 4620 images
# Checkpoint saved after 4630 images
# Checkpoint saved after 4640 images
# Checkpoint saved after 4650 images
# Checkpoint saved after 4660 images
# Checkpoint saved after 4670 images
# Checkpoint saved after 4680 images
# Checkpoint saved after 4690 images
# Checkpoint saved after 4700 images
# Checkpoint saved after 4710 images
# Checkpoint saved after 4720 images
# Checkpoint saved after 4730 images
# Checkpoint saved after 4740 images
# Checkpoint saved after 4750 images
# Checkpoint saved after 4760 images
# Checkpoint saved after 4770 images
# Checkpoint saved after 4780 images
# Checkpoint saved after 4790 images
# Checkpoint saved after 4800 images
# Checkpoint saved after 4810 images
# Checkpoint saved after 4820 images
# Checkpoint saved after 4830 images
# Checkpoint saved after 4840 images
# Checkpoint saved after 4850 images
# Checkpoint saved after 4860 images
# Checkpoint saved after 4870 images
# Checkpoint saved after 4880 images
# Checkpoint saved after 4890 images
# Checkpoint saved after 4900 images
# Checkpoint saved after 4910 images
# Checkpoint saved after 4920 images
# Checkpoint saved after 4930 images
# Checkpoint saved after 4940 images
# Checkpoint saved after 4950 images
# Checkpoint saved after 4960 images
# Checkpoint saved after 4970 images
# Checkpoint saved after 4980 images
# Checkpoint saved after 4990 images
# Checkpoint saved after 5000 images
# Checkpoint saved after 5010 images
# Checkpoint saved after 5020 images
# Checkpoint saved after 5030 images
# Checkpoint saved after 5040 images
# Checkpoint saved after 5050 images
# Checkpoint saved after 5060 images
# Checkpoint saved after 5070 images
# Checkpoint saved after 5080 images
# Checkpoint saved after 5090 images
# Checkpoint saved after 5100 images
# Checkpoint saved after 5110 images
# Checkpoint saved after 5120 images
# Checkpoint saved after 5130 images
# Checkpoint saved after 5140 images
# Checkpoint saved after 5150 images
# Checkpoint saved after 5160 images
# Checkpoint saved after 5170 images
# Checkpoint saved after 5180 images
# Checkpoint saved after 5190 images
# Checkpoint saved after 5200 images
# Checkpoint saved after 5210 images
# Checkpoint saved after 5220 images
# Checkpoint saved after 5230 images
# Checkpoint saved after 5240 images
# Checkpoint saved after 5250 images
# Checkpoint saved after 5260 images
# Checkpoint saved after 5270 images
# Checkpoint saved after 5280 images
# Checkpoint saved after 5290 images
# Checkpoint saved after 5300 images
# Checkpoint saved after 5310 images
# Checkpoint saved after 5320 images
# Checkpoint saved after 5330 images
# Checkpoint saved after 5340 images
# Checkpoint saved after 5350 images
# Checkpoint saved after 5360 images
# Checkpoint saved after 5370 images
# Checkpoint saved after 5380 images
# Checkpoint saved after 5390 images
# Checkpoint saved after 5400 images
# Checkpoint saved after 5410 images
# Checkpoint saved after 5420 images
# Checkpoint saved after 5430 images
# Checkpoint saved after 5440 images
# Checkpoint saved after 5450 images
# Checkpoint saved after 5460 images
# Checkpoint saved after 5470 images
# Checkpoint saved after 5480 images
# Checkpoint saved after 5490 images
# Checkpoint saved after 5500 images
# Checkpoint saved after 5510 images
# Checkpoint saved after 5520 images
# Checkpoint saved after 5530 images
# Checkpoint saved after 5540 images
# Checkpoint saved after 5550 images
# Checkpoint saved after 5560 images
# Checkpoint saved after 5570 images
# Checkpoint saved after 5580 images
# Checkpoint saved after 5590 images
# Checkpoint saved after 5600 images
# Checkpoint saved after 5610 images
# Checkpoint saved after 5620 images
# Checkpoint saved after 5630 images
# Checkpoint saved after 5640 images
# Checkpoint saved after 5650 images
# Checkpoint saved after 5660 images
# Checkpoint saved after 5670 images
# Checkpoint saved after 5680 images
# Checkpoint saved after 5690 images
# Checkpoint saved after 5700 images
# Checkpoint saved after 5710 images
# Checkpoint saved after 5720 images
# Checkpoint saved after 5730 images
# Checkpoint saved after 5740 images
# Checkpoint saved after 5750 images
# Checkpoint saved after 5760 images
# Checkpoint saved after 5770 images
# Checkpoint saved after 5780 images
# Checkpoint saved after 5790 images
# Checkpoint saved after 5800 images
# Checkpoint saved after 5810 images
# Checkpoint saved after 5820 images
# Checkpoint saved after 5830 images
# Checkpoint saved after 5840 images
# Checkpoint saved after 5850 images
# Checkpoint saved after 5860 images
# Checkpoint saved after 5870 images
# Checkpoint saved after 5880 images
# Checkpoint saved after 5890 images
# Checkpoint saved after 5900 images
# Checkpoint saved after 5910 images
# Checkpoint saved after 5920 images
# Checkpoint saved after 5930 images
# Checkpoint saved after 5940 images
# Checkpoint saved after 5950 images
# Checkpoint saved after 5960 images
# Checkpoint saved after 5970 images
# Checkpoint saved after 5980 images
# Checkpoint saved after 5990 images
# Checkpoint saved after 6000 images
# Checkpoint saved after 6010 images
# Checkpoint saved after 6020 images
# Checkpoint saved after 6030 images
# Checkpoint saved after 6040 images
# Checkpoint saved after 6050 images
# Checkpoint saved after 6060 images
# Checkpoint saved after 6070 images
# Checkpoint saved after 6080 images
# Checkpoint saved after 6090 images
# Checkpoint saved after 6100 images
# Checkpoint saved after 6110 images
# Checkpoint saved after 6120 images
# Checkpoint saved after 6130 images
# Checkpoint saved after 6140 images
# Checkpoint saved after 6150 images
# Checkpoint saved after 6160 images
# Checkpoint saved after 6170 images
# Checkpoint saved after 6180 images
# Checkpoint saved after 6190 images
# Checkpoint saved after 6200 images
# Checkpoint saved after 6210 images
# Checkpoint saved after 6220 images
# Checkpoint saved after 6230 images
# Checkpoint saved after 6240 images
# Checkpoint saved after 6250 images
# Checkpoint saved after 6260 images
# Checkpoint saved after 6270 images
# Checkpoint saved after 6280 images
# Checkpoint saved after 6290 images
# Checkpoint saved after 6300 images
# Checkpoint saved after 6310 images
# Checkpoint saved after 6320 images
# Checkpoint saved after 6330 images
# Checkpoint saved after 6340 images
# Checkpoint saved after 6350 images
# Checkpoint saved after 6360 images
# Checkpoint saved after 6370 images
# Checkpoint saved after 6380 images
# Checkpoint saved after 6390 images
# Checkpoint saved after 6400 images
# Checkpoint saved after 6410 images
# Checkpoint saved after 6420 images
# Checkpoint saved after 6430 images
# Checkpoint saved after 6440 images
# Checkpoint saved after 6450 images
# Checkpoint saved after 6460 images
# Checkpoint saved after 6470 images
# Checkpoint saved after 6480 images
# Checkpoint saved after 6490 images
# Checkpoint saved after 6500 images
# Checkpoint saved after 6510 images
# Checkpoint saved after 6520 images
# Checkpoint saved after 6530 images
# Checkpoint saved after 6540 images
# Checkpoint saved after 6550 images
# Checkpoint saved after 6560 images
# Checkpoint saved after 6570 images
# Checkpoint saved after 6580 images
# Checkpoint saved after 6590 images
# Checkpoint saved after 6600 images
# Checkpoint saved after 6610 images
# Checkpoint saved after 6620 images
# Checkpoint saved after 6630 images
# Checkpoint saved after 6640 images
# Checkpoint saved after 6650 images
# Checkpoint saved after 6660 images
# Checkpoint saved after 6670 images
# Checkpoint saved after 6680 images
# Checkpoint saved after 6690 images
# Checkpoint saved after 6700 images
# Checkpoint saved after 6710 images
# Checkpoint saved after 6720 images
# Checkpoint saved after 6730 images
# Checkpoint saved after 6740 images
# Checkpoint saved after 6750 images
# Checkpoint saved after 6760 images
# Checkpoint saved after 6770 images
# Checkpoint saved after 6780 images
# Checkpoint saved after 6790 images
# Checkpoint saved after 6800 images
# Checkpoint saved after 6810 images
# Checkpoint saved after 6820 images
# Checkpoint saved after 6830 images
# Checkpoint saved after 6840 images
# Checkpoint saved after 6850 images
# Checkpoint saved after 6860 images
# Checkpoint saved after 6870 images
# Checkpoint saved after 6880 images
# Checkpoint saved after 6890 images
# Checkpoint saved after 6900 images
# Checkpoint saved after 6910 images
# Checkpoint saved after 6920 images
# Checkpoint saved after 6930 images
# Checkpoint saved after 6940 images
# Checkpoint saved after 6950 images
# Checkpoint saved after 6960 images
# Checkpoint saved after 6970 images
# Checkpoint saved after 6980 images
# Checkpoint saved after 6990 images
# Checkpoint saved after 7000 images
# Checkpoint saved after 7010 images
# Checkpoint saved after 7020 images
# Checkpoint saved after 7030 images
# Checkpoint saved after 7040 images
# Checkpoint saved after 7050 images
# Checkpoint saved after 7060 images
# Checkpoint saved after 7070 images
# Checkpoint saved after 7080 images
# Checkpoint saved after 7090 images
# Checkpoint saved after 7100 images
# Checkpoint saved after 7110 images
# Checkpoint saved after 7120 images
# Checkpoint saved after 7130 images
# Checkpoint saved after 7140 images
# Checkpoint saved after 7150 images
# Checkpoint saved after 7160 images
# Checkpoint saved after 7170 images
# Checkpoint saved after 7180 images
# Checkpoint saved after 7190 images
# Checkpoint saved after 7200 images
# Checkpoint saved after 7210 images
# Checkpoint saved after 7220 images
# Checkpoint saved after 7230 images
# Checkpoint saved after 7240 images
# Checkpoint saved after 7250 images
# Checkpoint saved after 7260 images
# Checkpoint saved after 7270 images
# Checkpoint saved after 7280 images
# Checkpoint saved after 7290 images
# Checkpoint saved after 7300 images
# Checkpoint saved after 7310 images
# Checkpoint saved after 7320 images
# Checkpoint saved after 7330 images
# Checkpoint saved after 7340 images
# Checkpoint saved after 7350 images
# Checkpoint saved after 7360 images
# Checkpoint saved after 7370 images
# Checkpoint saved after 7380 images
# Checkpoint saved after 7390 images
# Checkpoint saved after 7400 images
# Checkpoint saved after 7410 images
# Checkpoint saved after 7420 images
# Checkpoint saved after 7430 images
# Checkpoint saved after 7440 images
# Checkpoint saved after 7450 images
# Checkpoint saved after 7460 images
# Checkpoint saved after 7470 images
# Checkpoint saved after 7480 images
# Checkpoint saved after 7490 images
# Checkpoint saved after 7500 images
# Checkpoint saved after 7510 images
# Checkpoint saved after 7520 images
# Checkpoint saved after 7530 images
# Checkpoint saved after 7540 images
# Checkpoint saved after 7550 images
# Checkpoint saved after 7560 images
# Checkpoint saved after 7570 images
# Checkpoint saved after 7580 images
# Checkpoint saved after 7590 images
# Checkpoint saved after 7600 images
# Checkpoint saved after 7610 images
# Checkpoint saved after 7620 images
# Checkpoint saved after 7630 images
# Checkpoint saved after 7640 images
# Checkpoint saved after 7650 images
# Checkpoint saved after 7660 images
# Checkpoint saved after 7670 images
# Checkpoint saved after 7680 images
# Checkpoint saved after 7690 images
# Checkpoint saved after 7700 images
# Checkpoint saved after 7710 images
# Checkpoint saved after 7720 images
# Checkpoint saved after 7730 images
# Checkpoint saved after 7740 images
# Checkpoint saved after 7750 images
# Checkpoint saved after 7760 images
# Checkpoint saved after 7770 images
# Checkpoint saved after 7780 images
# Checkpoint saved after 7790 images
# Checkpoint saved after 7800 images
# Checkpoint saved after 7810 images
# Checkpoint saved after 7820 images
# Checkpoint saved after 7830 images
# Checkpoint saved after 7840 images
# Checkpoint saved after 7850 images
# Checkpoint saved after 7860 images
# Checkpoint saved after 7870 images
# Checkpoint saved after 7880 images
# Checkpoint saved after 7890 images
# Checkpoint saved after 7900 images
# Checkpoint saved after 7910 images
# Checkpoint saved after 7920 images
# Checkpoint saved after 7930 images
# Checkpoint saved after 7940 images
# Checkpoint saved after 7950 images
# Checkpoint saved after 7960 images
# Checkpoint saved after 7970 images
# Checkpoint saved after 7980 images
# Checkpoint saved after 7990 images
# Checkpoint saved after 8000 images
# Checkpoint saved after 8010 images
# Checkpoint saved after 8020 images
# Checkpoint saved after 8030 images
# Checkpoint saved after 8040 images
# Checkpoint saved after 8050 images
# Checkpoint saved after 8060 images
# Checkpoint saved after 8070 images
# Checkpoint saved after 8080 images
# Checkpoint saved after 8090 images
# Checkpoint saved after 8100 images
# Checkpoint saved after 8110 images
# Checkpoint saved after 8120 images
# Checkpoint saved after 8130 images
# Checkpoint saved after 8140 images
# Checkpoint saved after 8150 images
# Checkpoint saved after 8160 images
# Checkpoint saved after 8170 images
# Checkpoint saved after 8180 images
# Checkpoint saved after 8190 images
# Checkpoint saved after 8200 images
# Checkpoint saved after 8210 images
# Checkpoint saved after 8220 images
# Checkpoint saved after 8230 images
# Checkpoint saved after 8240 images
# Checkpoint saved after 8250 images
# Checkpoint saved after 8260 images
# Checkpoint saved after 8270 images
# Checkpoint saved after 8280 images
# Checkpoint saved after 8290 images
# Checkpoint saved after 8300 images
# Checkpoint saved after 8310 images
# Checkpoint saved after 8320 images
# Checkpoint saved after 8330 images
# Checkpoint saved after 8340 images
# Checkpoint saved after 8350 images
# Checkpoint saved after 8360 images
# Checkpoint saved after 8370 images
# Checkpoint saved after 8380 images
# Checkpoint saved after 8390 images
# Checkpoint saved after 8400 images
# Checkpoint saved after 8410 images
# Checkpoint saved after 8420 images
# Checkpoint saved after 8430 images
# Checkpoint saved after 8440 images
# Checkpoint saved after 8450 images
# Checkpoint saved after 8460 images
# Checkpoint saved after 8470 images
# Checkpoint saved after 8480 images
# Checkpoint saved after 8490 images
# Checkpoint saved after 8500 images
# Checkpoint saved after 8510 images
# Checkpoint saved after 8520 images
# Checkpoint saved after 8530 images
# Checkpoint saved after 8540 images
# Checkpoint saved after 8550 images
# Checkpoint saved after 8560 images
# Checkpoint saved after 8570 images
# Checkpoint saved after 8580 images
# Checkpoint saved after 8590 images
# Checkpoint saved after 8600 images
# Checkpoint saved after 8610 images
# Checkpoint saved after 8620 images
# Checkpoint saved after 8630 images
# Checkpoint saved after 8640 images
# Checkpoint saved after 8650 images
# Checkpoint saved after 8660 images
# Checkpoint saved after 8670 images
# Checkpoint saved after 8680 images
# Checkpoint saved after 8690 images
# Checkpoint saved after 8700 images
# Checkpoint saved after 8710 images
# Checkpoint saved after 8720 images
# Checkpoint saved after 8730 images
# Checkpoint saved after 8740 images
# Checkpoint saved after 8750 images
# Checkpoint saved after 8760 images
# Checkpoint saved after 8770 images
# Checkpoint saved after 8780 images
# Checkpoint saved after 8790 images
# Checkpoint saved after 8800 images
# Checkpoint saved after 8810 images
# Checkpoint saved after 8820 images
# Checkpoint saved after 8830 images
# Checkpoint saved after 8840 images
# Checkpoint saved after 8850 images
# Checkpoint saved after 8860 images
# Checkpoint saved after 8870 images
# Checkpoint saved after 8880 images
# Checkpoint saved after 8890 images
# Checkpoint saved after 8900 images
# Checkpoint saved after 8910 images
# Checkpoint saved after 8920 images
# Checkpoint saved after 8930 images
# Checkpoint saved after 8940 images
# Checkpoint saved after 8950 images
# Checkpoint saved after 8960 images
# Checkpoint saved after 8970 images
# Checkpoint saved after 8980 images
# Checkpoint saved after 8990 images
# Checkpoint saved after 9000 images
# Checkpoint saved after 9010 images
# Checkpoint saved after 9020 images
# Checkpoint saved after 9030 images
# Checkpoint saved after 9040 images
# Checkpoint saved after 9050 images
# Checkpoint saved after 9060 images
# Checkpoint saved after 9070 images
# Checkpoint saved after 9080 images
# Checkpoint saved after 9090 images
# Checkpoint saved after 9100 images
# Checkpoint saved after 9110 images
# Checkpoint saved after 9120 images
# Checkpoint saved after 9130 images
# Checkpoint saved after 9140 images
# Checkpoint saved after 9150 images
# Checkpoint saved after 9160 images
# Checkpoint saved after 9170 images
# Checkpoint saved after 9180 images
# Checkpoint saved after 9190 images
# Checkpoint saved after 9200 images
# Checkpoint saved after 9210 images
# Checkpoint saved after 9220 images
# Checkpoint saved after 9230 images
# Checkpoint saved after 9240 images
# Checkpoint saved after 9250 images
# Checkpoint saved after 9260 images
# Checkpoint saved after 9270 images
# Checkpoint saved after 9280 images
# Checkpoint saved after 9290 images
# Checkpoint saved after 9300 images
# Checkpoint saved after 9310 images
# Checkpoint saved after 9320 images
# Checkpoint saved after 9330 images
# Checkpoint saved after 9340 images
# Checkpoint saved after 9350 images
# Checkpoint saved after 9360 images
# Checkpoint saved after 9370 images
# Checkpoint saved after 9380 images
# Checkpoint saved after 9390 images
# Checkpoint saved after 9400 images
# Checkpoint saved after 9410 images
# Checkpoint saved after 9420 images
# Checkpoint saved after 9430 images
# Checkpoint saved after 9440 images
# Checkpoint saved after 9450 images
# Checkpoint saved after 9460 images
# Checkpoint saved after 9470 images
# Checkpoint saved after 9480 images
# Checkpoint saved after 9490 images
# Checkpoint saved after 9500 images
# Checkpoint saved after 9510 images
# Checkpoint saved after 9520 images
# Checkpoint saved after 9530 images
# Checkpoint saved after 9540 images
# Checkpoint saved after 9550 images
# Checkpoint saved after 9560 images
# Checkpoint saved after 9570 images
# Checkpoint saved after 9580 images
# Checkpoint saved after 9590 images
# Checkpoint saved after 9600 images
# Checkpoint saved after 9610 images
# Checkpoint saved after 9620 images
# Checkpoint saved after 9630 images
# Checkpoint saved after 9640 images
# Checkpoint saved after 9650 images
# Checkpoint saved after 9660 images
# Checkpoint saved after 9670 images
# Checkpoint saved after 9680 images
# Checkpoint saved after 9690 images
# Checkpoint saved after 9700 images
# Checkpoint saved after 9710 images
# Checkpoint saved after 9720 images
# Checkpoint saved after 9730 images
# Checkpoint saved after 9740 images
# Checkpoint saved after 9750 images
# Checkpoint saved after 9760 images
# Checkpoint saved after 9770 images
# Checkpoint saved after 9780 images
# Checkpoint saved after 9790 images
# Checkpoint saved after 9800 images
# Checkpoint saved after 9810 images
# Checkpoint saved after 9820 images
# Checkpoint saved after 9830 images
# Checkpoint saved after 9840 images
# Checkpoint saved after 9850 images
# Checkpoint saved after 9860 images
# Checkpoint saved after 9870 images
# Checkpoint saved after 9880 images
# Checkpoint saved after 9890 images
# Checkpoint saved after 9900 images
# Checkpoint saved after 9910 images
# Checkpoint saved after 9920 images
# Checkpoint saved after 9930 images
# Checkpoint saved after 9940 images
# Checkpoint saved after 9950 images
# Checkpoint saved after 9960 images
# Checkpoint saved after 9970 images
# Checkpoint saved after 9980 images
# Checkpoint saved after 9990 images
# Checkpoint saved after 10000 images
# Checkpoint saved after 10010 images
# Checkpoint saved after 10020 images
# Checkpoint saved after 10030 images
# Checkpoint saved after 10040 images
# Checkpoint saved after 10050 images
# Checkpoint saved after 10060 images
# Checkpoint saved after 10070 images
# Checkpoint saved after 10080 images
# Checkpoint saved after 10090 images
# Checkpoint saved after 10100 images
# Checkpoint saved after 10110 images
# Checkpoint saved after 10120 images
# Checkpoint saved after 10130 images
# Checkpoint saved after 10140 images
# Checkpoint saved after 10150 images
# Checkpoint saved after 10160 images
# Checkpoint saved after 10170 images
# Checkpoint saved after 10180 images
# Checkpoint saved after 10190 images
# Checkpoint saved after 10200 images
# Checkpoint saved after 10210 images
# Checkpoint saved after 10220 images
# Checkpoint saved after 10230 images
# Checkpoint saved after 10240 images
# Checkpoint saved after 10250 images
# Checkpoint saved after 10260 images
# Checkpoint saved after 10270 images
# Checkpoint saved after 10280 images
# Checkpoint saved after 10290 images
# Checkpoint saved after 10300 images
# Checkpoint saved after 10310 images
# Checkpoint saved after 10320 images
# Checkpoint saved after 10330 images
# Checkpoint saved after 10340 images
# Checkpoint saved after 10350 images
# Checkpoint saved after 10360 images
# Checkpoint saved after 10370 images
# Checkpoint saved after 10380 images
# Checkpoint saved after 10390 images
# Checkpoint saved after 10400 images
# Checkpoint saved after 10410 images
# Checkpoint saved after 10420 images
# Checkpoint saved after 10430 images
# Checkpoint saved after 10440 images
# Checkpoint saved after 10450 images
# Checkpoint saved after 10460 images
# Checkpoint saved after 10470 images
# Checkpoint saved after 10480 images
# Checkpoint saved after 10490 images
# Checkpoint saved after 10500 images
# Checkpoint saved after 10510 images
# Checkpoint saved after 10520 images
# Checkpoint saved after 10530 images
# Checkpoint saved after 10540 images
# Checkpoint saved after 10550 images
# Checkpoint saved after 10560 images
# Checkpoint saved after 10570 images
# Checkpoint saved after 10580 images
# Checkpoint saved after 10590 images
# Checkpoint saved after 10600 images
# Checkpoint saved after 10610 images
# Checkpoint saved after 10620 images
# Checkpoint saved after 10630 images
# Checkpoint saved after 10640 images
# Checkpoint saved after 10650 images
# Checkpoint saved after 10660 images
# Checkpoint saved after 10670 images
# Checkpoint saved after 10680 images
# Checkpoint saved after 10690 images
# Checkpoint saved after 10700 images
# Checkpoint saved after 10710 images
# Checkpoint saved after 10720 images
# Checkpoint saved after 10730 images
# Checkpoint saved after 10740 images
# Checkpoint saved after 10750 images
# Checkpoint saved after 10760 images
# Checkpoint saved after 10770 images
# Checkpoint saved after 10780 images
# Checkpoint saved after 10790 images
# Checkpoint saved after 10800 images
# Checkpoint saved after 10810 images
# Checkpoint saved after 10820 images
# Checkpoint saved after 10830 images
# Checkpoint saved after 10840 images
# Checkpoint saved after 10850 images
# Checkpoint saved after 10860 images
# Checkpoint saved after 10870 images
# Checkpoint saved after 10880 images
# Checkpoint saved after 10890 images
# Checkpoint saved after 10900 images
# Checkpoint saved after 10910 images
# Checkpoint saved after 10920 images
# Checkpoint saved after 10930 images
# Checkpoint saved after 10940 images
# Checkpoint saved after 10950 images
# Checkpoint saved after 10960 images
# Checkpoint saved after 10970 images
# Checkpoint saved after 10980 images
# Checkpoint saved after 10990 images
# Checkpoint saved after 11000 images
# Checkpoint saved after 11010 images
# Checkpoint saved after 11020 images
# Checkpoint saved after 11030 images
# Checkpoint saved after 11040 images
# Checkpoint saved after 11050 images
# Checkpoint saved after 11060 images
# Checkpoint saved after 11070 images
# Checkpoint saved after 11080 images
# Checkpoint saved after 11090 images
# Checkpoint saved after 11100 images
# Checkpoint saved after 11110 images
# Checkpoint saved after 11120 images
# Checkpoint saved after 11130 images
# Checkpoint saved after 11140 images
# Checkpoint saved after 11150 images
# Checkpoint saved after 11160 images
# Checkpoint saved after 11170 images
# Checkpoint saved after 11180 images
# Checkpoint saved after 11190 images
# Checkpoint saved after 11200 images
# Checkpoint saved after 11210 images
# Checkpoint saved after 11220 images
# Checkpoint saved after 11230 images
# Checkpoint saved after 11240 images
# Checkpoint saved after 11250 images
# Checkpoint saved after 11260 images
# Checkpoint saved after 11270 images
# Checkpoint saved after 11280 images
# Checkpoint saved after 11290 images
# Checkpoint saved after 11300 images
# Checkpoint saved after 11310 images
# Checkpoint saved after 11320 images
# Checkpoint saved after 11330 images
# Checkpoint saved after 11340 images
# Checkpoint saved after 11350 images
# Checkpoint saved after 11360 images
# Checkpoint saved after 11370 images
# Checkpoint saved after 11380 images
# Checkpoint saved after 11390 images
# Checkpoint saved after 11400 images
# Checkpoint saved after 11410 images
# Checkpoint saved after 11420 images
# Checkpoint saved after 11430 images
# Checkpoint saved after 11440 images
# Checkpoint saved after 11450 images
# Checkpoint saved after 11460 images
# Checkpoint saved after 11470 images
# Checkpoint saved after 11480 images
# Checkpoint saved after 11490 images
# Checkpoint saved after 11500 images
# Checkpoint saved after 11510 images
# Checkpoint saved after 11520 images
# Checkpoint saved after 11530 images
# Checkpoint saved after 11540 images
# Checkpoint saved after 11550 images
# Checkpoint saved after 11560 images
# Checkpoint saved after 11570 images
# Checkpoint saved after 11580 images
# Checkpoint saved after 11590 images
# Final embeddings saved

# %%
final_path = os.path.join(checkpoint_dir, 'embeddings_final.pkl')
with open(final_path, 'wb') as f:
    pickle.dump((image_names, embeddings), f)
print("Final embeddings saved")

# %% [markdown]
# # Embed Profile Images with ArcFace

# %%
# !pip install deepface
# !pip install face-face_recognition
# !pip install mediapipe
# !pip install opencv-python
# Out:
# Collecting deepface
#   Downloading deepface-0.0.92-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: requests>=2.27.1 in /usr/local/lib/python3.10/dist-packages (from deepface) (2.32.3)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from deepface) (1.26.4)
# Requirement already satisfied: pandas>=0.23.4 in /usr/local/lib/python3.10/dist-packages (from deepface) (2.1.4)
# Requirement already satisfied: gdown>=3.10.1 in /usr/local/lib/python3.10/dist-packages (from deepface) (5.1.0)
# Requirement already satisfied: tqdm>=4.30.0 in /usr/local/lib/python3.10/dist-packages (from deepface) (4.66.5)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from deepface) (9.4.0)
# Requirement already satisfied: opencv-python>=4.5.5.64 in /usr/local/lib/python3.10/dist-packages (from deepface) (4.10.0.84)
# Requirement already satisfied: tensorflow>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from deepface) (2.17.0)
# Requirement already satisfied: keras>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from deepface) (3.4.1)
# Requirement already satisfied: Flask>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from deepface) (2.2.5)
# Collecting mtcnn>=0.1.0 (from deepface)
#   Downloading mtcnn-0.1.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting retina-face>=0.0.1 (from deepface)
#   Downloading retina_face-0.0.17-py3-none-any.whl.metadata (10 kB)
# Collecting fire>=0.4.0 (from deepface)
#   Downloading fire-0.6.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 1.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gunicorn>=20.1.0 (from deepface)
#   Downloading gunicorn-22.0.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fire>=0.4.0->deepface) (1.16.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire>=0.4.0->deepface) (2.4.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from Flask>=1.1.2->deepface) (3.0.3)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from Flask>=1.1.2->deepface) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask>=1.1.2->deepface) (2.2.0)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from Flask>=1.1.2->deepface) (8.1.7)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown>=3.10.1->deepface) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown>=3.10.1->deepface) (3.15.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from gunicorn>=20.1.0->deepface) (24.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras>=2.2.0->deepface) (1.4.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=2.2.0->deepface) (13.7.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=2.2.0->deepface) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras>=2.2.0->deepface) (3.11.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=2.2.0->deepface) (0.12.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras>=2.2.0->deepface) (0.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23.4->deepface) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23.4->deepface) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.1->deepface) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.1->deepface) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.1->deepface) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.1->deepface) (2024.7.4)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->deepface) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->deepface) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->deepface) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->deepface) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->deepface) (71.0.4)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->deepface) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->deepface) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->deepface) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->deepface) (2.17.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->deepface) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow>=1.9.0->deepface) (0.44.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.0->Flask>=1.1.2->deepface) (2.1.5)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow>=1.9.0->deepface) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow>=1.9.0->deepface) (0.7.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=2.2.0->deepface) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=2.2.0->deepface) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=2.2.0->deepface) (0.1.2)
# Downloading deepface-0.0.92-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.5/105.5 kB 10.3 MB/s eta 0:00:00
# Downloading gunicorn-22.0.0-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.4/84.4 kB 7.4 MB/s eta 0:00:00
# Downloading mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 78.0 MB/s eta 0:00:00
# Downloading retina_face-0.0.17-py3-none-any.whl (25 kB)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117030 sha256=f7deb5d9d181df0d2c245c2a35508fbe830dd3364de2af4e539e3b79efd570fd
#   Stored in directory: /root/.cache/pip/wheels/d6/6d/5d/5b73fa0f46d01a793713f8859201361e9e581ced8c75e5c6a3
# Successfully built fire
# Installing collected packages: gunicorn, fire, mtcnn, retina-face, deepface
# Successfully installed deepface-0.0.92 fire-0.6.0 gunicorn-22.0.0 mtcnn-0.1.1 retina-face-0.0.17
# ERROR: Could not find a version that satisfies the requirement face-face_recognition (from versions: none)
# ERROR: No matching distribution found for face-face_recognition
# Collecting mediapipe
#   Downloading mediapipe-0.10.14-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (24.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (24.3.25)
# Requirement already satisfied: jax in /usr/local/lib/python3.10/dist-packages (from mediapipe) (0.4.26)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.10/dist-packages (from mediapipe) (0.4.26+cuda12.cudnn89)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mediapipe) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mediapipe) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from mediapipe) (4.10.0.84)
# Collecting protobuf<5,>=4.25.3 (from mediapipe)
#   Downloading protobuf-4.25.4-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Downloading sounddevice-0.4.7-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.10/dist-packages (from sounddevice>=0.4.4->mediapipe) (1.16.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe) (0.4.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe) (3.3.0)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Downloading mediapipe-0.10.14-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 62.9 MB/s eta 0:00:00
# Downloading protobuf-4.25.4-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 23.5 MB/s eta 0:00:00
# Downloading sounddevice-0.4.7-py3-none-any.whl (32 kB)
# Installing collected packages: protobuf, sounddevice, mediapipe
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-metadata 1.15.0 requires protobuf<4.21,>=3.20.3; python_version < "3.11", but you have protobuf 4.25.4 which is incompatible.
# Successfully installed mediapipe-0.10.14 protobuf-4.25.4 sounddevice-0.4.7
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.26.4)

# %%
import cv2
import os
import numpy as np
import mediapipe as mp
import matplotlib.pyplot as plt
import math
import shutil

from mediapipe.tasks import python
from mediapipe.tasks.python import vision

from typing import Tuple, Union
import math

from PIL import Image

# %%
from huggingface_hub import hf_hub_download

hf_hub_download(repo_id="FoivosPar/Arc2Face", filename="arc2face/config.json", local_dir="./models")
hf_hub_download(repo_id="FoivosPar/Arc2Face", filename="arc2face/diffusion_pytorch_model.safetensors", local_dir="./models")
hf_hub_download(repo_id="FoivosPar/Arc2Face", filename="encoder/config.json", local_dir="./models")
hf_hub_download(repo_id="FoivosPar/Arc2Face", filename="encoder/pytorch_model.bin", local_dir="./models")
# Out:
# Downloading arc2face/config.json:   0%|          | 0.00/1.78k [00:00<?, ?B/s]
# Downloading (…)ch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# Downloading encoder/config.json:   0%|          | 0.00/560 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/492M [00:00<?, ?B/s]
# './models/encoder/pytorch_model.bin'

# %%
# !git clone https://github.com/foivospar/Arc2Face.git

# !pip install -r /content/Arc2Face/requirements.txt
# Out:
# Cloning into 'Arc2Face'...
# remote: Enumerating objects: 120, done.
# remote: Counting objects: 100% (120/120), done.
# remote: Compressing objects: 100% (101/101), done.
# remote: Total 120 (delta 53), reused 59 (delta 16), pack-reused 0
# Receiving objects: 100% (120/120), 29.07 MiB | 14.46 MiB/s, done.
# Resolving deltas: 100% (53/53), done.
# Collecting numpy<1.24.0 (from -r /content/Arc2Face/requirements.txt (line 1))
#   Downloading numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# Collecting torch==2.0.1 (from -r /content/Arc2Face/requirements.txt (line 2))
#   Downloading torch-2.0.1-cp310-cp310-manylinux1_x86_64.whl.metadata (24 kB)
# Collecting torchvision==0.15.2 (from -r /content/Arc2Face/requirements.txt (line 3))
#   Downloading torchvision-0.15.2-cp310-cp310-manylinux1_x86_64.whl.metadata (11 kB)
# Collecting diffusers==0.23.0 (from -r /content/Arc2Face/requirements.txt (line 4))
#   Downloading diffusers-0.23.0-py3-none-any.whl.metadata (17 kB)
# Collecting transformers==4.34.1 (from -r /content/Arc2Face/requirements.txt (line 5))
#   Downloading transformers-4.34.1-py3-none-any.whl.metadata (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.5/121.5 kB 8.0 MB/s eta 0:00:00
# Collecting peft (from -r /content/Arc2Face/requirements.txt (line 6))
#   Downloading peft-0.12.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (from -r /content/Arc2Face/requirements.txt (line 7)) (0.32.1)
# Collecting insightface (from -r /content/Arc2Face/requirements.txt (line 8))
#   Downloading insightface-0.7.3.tar.gz (439 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.5/439.5 kB 36.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting onnxruntime-gpu (from -r /content/Arc2Face/requirements.txt (line 9))
#   Downloading onnxruntime_gpu-1.18.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.4 kB)
# Collecting gradio (from -r /content/Arc2Face/requirements.txt (line 10))
#   Downloading gradio-4.41.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->-r /content/Arc2Face/requirements.txt (line 2)) (3.15.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->-r /content/Arc2Face/requirements.txt (line 2)) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->-r /content/Arc2Face/requirements.txt (line 2)) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->-r /content/Arc2Face/requirements.txt (line 2)) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->-r /content/Arc2Face/requirements.txt (line 2)) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch==2.0.1->-r /content/Arc2Face/requirements.txt (line 2))
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch==2.0.1->-r /content/Arc2Face/requirements.txt (line 2))
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cuda-cupti-cu11==11.7.101 (from torch==2.0.1->-r /content/Arc2Face/requirements.txt (line 2))
#   Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch==2.0.1->-r /content/Arc2Face/requirements.txt (line 2))
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch==2.0.1->-r /content/Arc2Face/requirements.txt (line 2))
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cufft-cu11==10.9.0.58 (from torch==2.0.1->-r /content/Arc2Face/requirements.txt (line 2))
#   Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu11==10.2.10.91 (from torch==2.0.1->-r /content/Arc2Face/requirements.txt (line 2))
#   Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusolver-cu11==11.4.0.1 (from torch==2.0.1->-r /content/Arc2Face/requirements.txt (line 2))
#   Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu11==11.7.4.91 (from torch==2.0.1->-r /content/Arc2Face/requirements.txt (line 2))
#   Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu11==2.14.3 (from torch==2.0.1->-r /content/Arc2Face/requirements.txt (line 2))
#   Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu11==11.7.91 (from torch==2.0.1->-r /content/Arc2Face/requirements.txt (line 2))
#   Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.0.0 (from torch==2.0.1->-r /content/Arc2Face/requirements.txt (line 2))
#   Downloading triton-2.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.0 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision==0.15.2->-r /content/Arc2Face/requirements.txt (line 3)) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.15.2->-r /content/Arc2Face/requirements.txt (line 3)) (9.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers==0.23.0->-r /content/Arc2Face/requirements.txt (line 4)) (8.2.0)
# Requirement already satisfied: huggingface-hub>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.23.0->-r /content/Arc2Face/requirements.txt (line 4)) (0.23.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.23.0->-r /content/Arc2Face/requirements.txt (line 4)) (2024.5.15)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.23.0->-r /content/Arc2Face/requirements.txt (line 4)) (0.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.34.1->-r /content/Arc2Face/requirements.txt (line 5)) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.34.1->-r /content/Arc2Face/requirements.txt (line 5)) (6.0.1)
# Collecting tokenizers<0.15,>=0.14 (from transformers==4.34.1->-r /content/Arc2Face/requirements.txt (line 5))
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.34.1->-r /content/Arc2Face/requirements.txt (line 5)) (4.66.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->-r /content/Arc2Face/requirements.txt (line 2)) (71.0.4)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->-r /content/Arc2Face/requirements.txt (line 2)) (0.44.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1->-r /content/Arc2Face/requirements.txt (line 2)) (3.30.2)
# Collecting lit (from triton==2.0.0->torch==2.0.1->-r /content/Arc2Face/requirements.txt (line 2))
#   Downloading lit-18.1.8-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from peft->-r /content/Arc2Face/requirements.txt (line 6)) (5.9.5)
# Collecting onnx (from insightface->-r /content/Arc2Face/requirements.txt (line 8))
#   Downloading onnx-1.16.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from insightface->-r /content/Arc2Face/requirements.txt (line 8)) (3.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from insightface->-r /content/Arc2Face/requirements.txt (line 8)) (1.13.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from insightface->-r /content/Arc2Face/requirements.txt (line 8)) (1.3.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from insightface->-r /content/Arc2Face/requirements.txt (line 8)) (0.23.2)
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from insightface->-r /content/Arc2Face/requirements.txt (line 8)) (1.13)
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (from insightface->-r /content/Arc2Face/requirements.txt (line 8)) (3.0.11)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.10/dist-packages (from insightface->-r /content/Arc2Face/requirements.txt (line 8)) (1.4.12)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (from insightface->-r /content/Arc2Face/requirements.txt (line 8)) (3.10.2)
# Collecting coloredlogs (from onnxruntime-gpu->-r /content/Arc2Face/requirements.txt (line 9))
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime-gpu->-r /content/Arc2Face/requirements.txt (line 9)) (24.3.25)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime-gpu->-r /content/Arc2Face/requirements.txt (line 9)) (4.25.4)
# Collecting aiofiles<24.0,>=22.0 (from gradio->-r /content/Arc2Face/requirements.txt (line 10))
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio->-r /content/Arc2Face/requirements.txt (line 10)) (3.7.1)
# Collecting fastapi (from gradio->-r /content/Arc2Face/requirements.txt (line 10))
#   Downloading fastapi-0.112.0-py3-none-any.whl.metadata (27 kB)
# Collecting ffmpy (from gradio->-r /content/Arc2Face/requirements.txt (line 10))
#   Downloading ffmpy-0.4.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting gradio-client==1.3.0 (from gradio->-r /content/Arc2Face/requirements.txt (line 10))
#   Downloading gradio_client-1.3.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting httpx>=0.24.1 (from gradio->-r /content/Arc2Face/requirements.txt (line 10))
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio->-r /content/Arc2Face/requirements.txt (line 10)) (6.4.0)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio->-r /content/Arc2Face/requirements.txt (line 10)) (2.1.5)
# Collecting orjson~=3.0 (from gradio->-r /content/Arc2Face/requirements.txt (line 10))
#   Downloading orjson-3.10.7.tar.gz (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 106.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (pyproject.toml) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !mkdir -p ./models/antelopev2
# !cp -r /content/drive/MyDrive/models/antelopev2/* /content/models/antelopev2

from huggingface_hub import hf_hub_download
hf_hub_download(repo_id="FoivosPar/Arc2Face", filename="arcface.onnx", local_dir="./models/antelopev2")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# arcface.onnx:   0%|          | 0.00/261M [00:00<?, ?B/s]
# 'models/antelopev2/arcface.onnx'

# %%
# !pip uninstall transformers huggingface_hub
# !pip install transformers huggingface_hub
# Out:
# Found existing installation: transformers 4.44.0
# Uninstalling transformers-4.44.0:
#   Would remove:
#     /usr/local/bin/transformers-cli
#     /usr/local/lib/python3.10/dist-packages/transformers-4.44.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/transformers/*
# Proceed (Y/n)? Y
#   Successfully uninstalled transformers-4.44.0
# Found existing installation: huggingface-hub 0.24.5
# Uninstalling huggingface-hub-0.24.5:
#   Would remove:
#     /usr/local/bin/huggingface-cli
#     /usr/local/lib/python3.10/dist-packages/huggingface_hub-0.24.5.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/huggingface_hub/*
# Proceed (Y/n)? Y
#   Successfully uninstalled huggingface-hub-0.24.5
# Collecting transformers
#   Using cached transformers-4.44.0-py3-none-any.whl.metadata (43 kB)
# Collecting huggingface_hub
#   Using cached huggingface_hub-0.24.5-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.7.4)
# Using cached transformers-4.44.0-py3-none-any.whl (9.5 MB)
# Using cached huggingface_hub-0.24.5-py3-none-any.whl (417 kB)
# Installing collected packages: huggingface_hub, transformers
# Successfully installed huggingface_hub-0.24.5 transformers-4.44.0

# %%
# !pip install transformers==4.33.0
# Out:
# Collecting transformers==4.33.0
#   Downloading transformers-4.33.0-py3-none-any.whl.metadata (119 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.9/119.9 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.33.0) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.33.0) (0.24.5)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.33.0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.33.0) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.33.0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.33.0) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.33.0) (2.32.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.33.0) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.33.0) (0.4.4)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.33.0) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers==4.33.0) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers==4.33.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.33.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.33.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.33.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.33.0) (2024.7.4)
# Downloading transformers-4.33.0-py3-none-any.whl (7.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 108.6 MB/s eta 0:00:00
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.28.0
#     Uninstalling transformers-4.28.0:
#       Successfully uninstalled transformers-4.28.0
# Successfully installed transformers-4.33.0

# %%
import sys
sys.path.append('/content/Arc2Face')

# %%
import insightface
from insightface.app import FaceAnalysis
from arc2face import CLIPTextModelWrapper, project_face_embs
import torch
from PIL import Image
import numpy as np
import os
import cv2
from insightface.app.face_analysis import Face

import json
import logging
from tqdm.notebook import tqdm
import pickle

# %%
app = FaceAnalysis(name='antelopev2', root='./', providers=['CUDAExecutionProvider', 'CPUExecutionProvider'])
app.prepare(ctx_id=0, det_size=(128, 128))

def generate_embedding(imgpath):
    img = np.array(Image.open(imgpath))[:,:,::-1]
    faces = app.get(img)
    if faces:
        id_emb = torch.tensor(faces[0]['embedding'], dtype=torch.float32)[None].cuda()
        id_emb = id_emb / torch.norm(id_emb, dim=1, keepdim=True)
        id_emb = id_emb.cpu()
        return id_emb
    return None
# Out:
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'use_tf32': '1', 'prefer_nhwc': '0', 'tunable_op_max_tuning_duration_ms': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_tuning_enable': '0', 'tunable_op_enable': '0', 'use_ep_level_unified_stream': '0', 'device_id': '0', 'has_user_compute_stream': '0', 'gpu_external_empty_cache': '0', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_alloc': '0', 'gpu_external_free': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'do_copy_in_default_stream': '1', 'enable_cuda_graph': '0', 'user_compute_stream': '0', 'cudnn_conv_use_max_workspace': '1'}}
# find model: ./models/antelopev2/1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'use_tf32': '1', 'prefer_nhwc': '0', 'tunable_op_max_tuning_duration_ms': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_tuning_enable': '0', 'tunable_op_enable': '0', 'use_ep_level_unified_stream': '0', 'device_id': '0', 'has_user_compute_stream': '0', 'gpu_external_empty_cache': '0', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_alloc': '0', 'gpu_external_free': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'do_copy_in_default_stream': '1', 'enable_cuda_graph': '0', 'user_compute_stream': '0', 'cudnn_conv_use_max_workspace': '1'}}
# find model: ./models/antelopev2/2d106det.onnx landmark_2d_106 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'use_tf32': '1', 'prefer_nhwc': '0', 'tunable_op_max_tuning_duration_ms': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_tuning_enable': '0', 'tunable_op_enable': '0', 'use_ep_level_unified_stream': '0', 'device_id': '0', 'has_user_compute_stream': '0', 'gpu_external_empty_cache': '0', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_alloc': '0', 'gpu_external_free': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'do_copy_in_default_stream': '1', 'enable_cuda_graph': '0', 'user_compute_stream': '0', 'cudnn_conv_use_max_workspace': '1'}}
# find model: ./models/antelopev2/arcface.onnx recognition ['None', 3, 112, 112] 127.5 127.5
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'use_tf32': '1', 'prefer_nhwc': '0', 'tunable_op_max_tuning_duration_ms': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_tuning_enable': '0', 'tunable_op_enable': '0', 'use_ep_level_unified_stream': '0', 'device_id': '0', 'has_user_compute_stream': '0', 'gpu_external_empty_cache': '0', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_alloc': '0', 'gpu_external_free': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'do_copy_in_default_stream': '1', 'enable_cuda_graph': '0', 'user_compute_stream': '0', 'cudnn_conv_use_max_workspace': '1'}}
# find model: ./models/antelopev2/genderage.onnx genderage ['None', 3, 96, 96] 0.0 1.0
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'use_tf32': '1', 'prefer_nhwc': '0', 'tunable_op_max_tuning_duration_ms': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_tuning_enable': '0', 'tunable_op_enable': '0', 'use_ep_level_unified_stream': '0', 'device_id': '0', 'has_user_compute_stream': '0', 'gpu_external_empty_cache': '0', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_alloc': '0', 'gpu_external_free': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'do_copy_in_default_stream': '1', 'enable_cuda_graph': '0', 'user_compute_stream': '0', 'cudnn_conv_use_max_workspace': '1'}}
# find model: ./models/antelopev2/scrfd_10g_bnkps.onnx detection [1, 3, '?', '?'] 127.5 128.0
# set det-size: (128, 128)

# %%
def process_images_in_folder(folder_path, checkpoint_dir):
    embeddings = []
    image_names = []
    checkpoint_interval = 10
    checkpoint_path = os.path.join(checkpoint_dir, 'embeddings_checkpoint.pkl')

    os.makedirs(checkpoint_dir, exist_ok=True)

    # Load checkpoint if it exists
    if os.path.exists(checkpoint_path):
        with open(checkpoint_path, 'rb') as f:
            image_names, embeddings = pickle.load(f)
        print(f"Checkpoint loaded. Resuming from {len(image_names)} images.")

    all_image_files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

    # Filter out images that are already processed
    processed_images = set(image_names)
    image_files = [f for f in all_image_files if f not in processed_images]

    # Process images with progress
    for i, image_file in enumerate(tqdm(image_files, desc="Processing images", initial=len(processed_images), total=len(all_image_files))):
        imgpath = os.path.join(folder_path, image_file)
        embedding = generate_embedding(imgpath)
        if embedding is not None:
            embeddings.append(embedding.numpy())
            image_names.append(image_file)

        # Save checkpoint every checkpoint_interval embeddings
        if (len(image_names)) % checkpoint_interval == 0:
            with open(checkpoint_path, 'wb') as f:
                pickle.dump((image_names, embeddings), f)
            print(f"Checkpoint saved after {len(image_names)} images")

    # Save final embeddings
    final_path = os.path.join(checkpoint_dir, 'embeddings_final.pkl')
    with open(final_path, 'wb') as f:
        pickle.dump((image_names, embeddings), f)
    print("Final embeddings saved")

folder_path = '/content/drive/MyDrive/faces/NYPD_profile_imgs'
checkpoint_dir = '/content/drive/MyDrive/faces/emb_checkpoints'
process_images_in_folder(folder_path, checkpoint_dir)
# Out:
# Processing images:   0%|          | 0/11699 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/insightface/utils/transform.py:68: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   P = np.linalg.lstsq(X_homo, Y)[0].T # Affine matrix. 3 x 4
# Checkpoint saved after 10 images
# Checkpoint saved after 20 images
# Checkpoint saved after 30 images
# Checkpoint saved after 40 images
# Checkpoint saved after 50 images
# Checkpoint saved after 60 images
# Checkpoint saved after 70 images
# Checkpoint saved after 80 images
# Checkpoint saved after 90 images
# Checkpoint saved after 100 images
# Checkpoint saved after 110 images
# Checkpoint saved after 120 images
# Checkpoint saved after 130 images
# Checkpoint saved after 140 images
# Checkpoint saved after 150 images
# Checkpoint saved after 160 images
# Checkpoint saved after 170 images
# Checkpoint saved after 180 images
# Checkpoint saved after 190 images
# Checkpoint saved after 200 images
# Checkpoint saved after 210 images
# Checkpoint saved after 220 images
# Checkpoint saved after 230 images
# Checkpoint saved after 240 images
# Checkpoint saved after 250 images
# Checkpoint saved after 260 images
# Checkpoint saved after 270 images
# Checkpoint saved after 280 images
# Checkpoint saved after 290 images
# Checkpoint saved after 300 images
# Checkpoint saved after 310 images
# Checkpoint saved after 320 images
# Checkpoint saved after 330 images
# Checkpoint saved after 340 images
# Checkpoint saved after 350 images
# Checkpoint saved after 360 images
# Checkpoint saved after 370 images
# Checkpoint saved after 380 images
# Checkpoint saved after 390 images
# Checkpoint saved after 400 images
# Checkpoint saved after 410 images
# Checkpoint saved after 420 images
# Checkpoint saved after 430 images
# Checkpoint saved after 440 images
# Checkpoint saved after 450 images
# Checkpoint saved after 460 images
# Checkpoint saved after 470 images
# Checkpoint saved after 480 images
# Checkpoint saved after 490 images
# Checkpoint saved after 500 images
# Checkpoint saved after 510 images
# Checkpoint saved after 520 images
# Checkpoint saved after 530 images
# Checkpoint saved after 540 images
# Checkpoint saved after 550 images
# Checkpoint saved after 560 images
# Checkpoint saved after 570 images
# Checkpoint saved after 580 images
# Checkpoint saved after 590 images
# Checkpoint saved after 600 images
# Checkpoint saved after 610 images
# Checkpoint saved after 620 images
# Checkpoint saved after 630 images
# Checkpoint saved after 640 images
# Checkpoint saved after 650 images
# Checkpoint saved after 660 images
# Checkpoint saved after 670 images
# Checkpoint saved after 680 images
# Checkpoint saved after 690 images
# Checkpoint saved after 700 images
# Checkpoint saved after 710 images
# Checkpoint saved after 720 images
# Checkpoint saved after 730 images
# Checkpoint saved after 740 images
# Checkpoint saved after 750 images
# Checkpoint saved after 760 images
# Checkpoint saved after 770 images
# Checkpoint saved after 780 images
# Checkpoint saved after 790 images
# Checkpoint saved after 800 images
# Checkpoint saved after 810 images
# Checkpoint saved after 820 images
# Checkpoint saved after 830 images
# Checkpoint saved after 840 images
# Checkpoint saved after 850 images
# Checkpoint saved after 860 images
# Checkpoint saved after 870 images
# Checkpoint saved after 880 images
# Checkpoint saved after 890 images
# Checkpoint saved after 900 images
# Checkpoint saved after 910 images
# Checkpoint saved after 920 images
# Checkpoint saved after 930 images
# Checkpoint saved after 940 images
# Checkpoint saved after 950 images
# Checkpoint saved after 960 images
# Checkpoint saved after 970 images
# Checkpoint saved after 980 images
# Checkpoint saved after 990 images
# Checkpoint saved after 1000 images
# Checkpoint saved after 1010 images
# Checkpoint saved after 1020 images
# Checkpoint saved after 1030 images
# Checkpoint saved after 1040 images
# Checkpoint saved after 1050 images
# Checkpoint saved after 1060 images
# Checkpoint saved after 1070 images
# Checkpoint saved after 1080 images
# Checkpoint saved after 1090 images
# Checkpoint saved after 1100 images
# Checkpoint saved after 1110 images
# Checkpoint saved after 1120 images
# Checkpoint saved after 1130 images
# Checkpoint saved after 1140 images
# Checkpoint saved after 1150 images
# Checkpoint saved after 1160 images
# Checkpoint saved after 1170 images
# Checkpoint saved after 1180 images
# Checkpoint saved after 1190 images
# Checkpoint saved after 1200 images
# Checkpoint saved after 1210 images
# Checkpoint saved after 1220 images
# Checkpoint saved after 1230 images
# Checkpoint saved after 1240 images
# Checkpoint saved after 1250 images
# Checkpoint saved after 1260 images
# Checkpoint saved after 1270 images
# Checkpoint saved after 1280 images
# Checkpoint saved after 1290 images
# Checkpoint saved after 1300 images
# Checkpoint saved after 1310 images
# Checkpoint saved after 1320 images
# Checkpoint saved after 1330 images
# Checkpoint saved after 1340 images
# Checkpoint saved after 1350 images
# Checkpoint saved after 1360 images
# Checkpoint saved after 1370 images
# Checkpoint saved after 1380 images
# Checkpoint saved after 1390 images
# Checkpoint saved after 1400 images
# Checkpoint saved after 1410 images
# Checkpoint saved after 1420 images
# Checkpoint saved after 1430 images
# Checkpoint saved after 1440 images
# Checkpoint saved after 1450 images
# Checkpoint saved after 1460 images
# Checkpoint saved after 1470 images
# Checkpoint saved after 1480 images
# Checkpoint saved after 1490 images
# Checkpoint saved after 1500 images
# Checkpoint saved after 1510 images
# Checkpoint saved after 1520 images
# Checkpoint saved after 1530 images
# Checkpoint saved after 1540 images
# Checkpoint saved after 1550 images
# Checkpoint saved after 1560 images
# Checkpoint saved after 1570 images
# Checkpoint saved after 1580 images
# Checkpoint saved after 1590 images
# Checkpoint saved after 1600 images
# Checkpoint saved after 1610 images
# Checkpoint saved after 1620 images
# Checkpoint saved after 1630 images
# Checkpoint saved after 1640 images
# Checkpoint saved after 1650 images
# Checkpoint saved after 1650 images
# Checkpoint saved after 1660 images
# Checkpoint saved after 1670 images
# Checkpoint saved after 1680 images
# Checkpoint saved after 1690 images
# Checkpoint saved after 1700 images
# Checkpoint saved after 1710 images
# Checkpoint saved after 1720 images
# Checkpoint saved after 1730 images
# Checkpoint saved after 1740 images
# Checkpoint saved after 1750 images
# Checkpoint saved after 1760 images
# Checkpoint saved after 1770 images
# Checkpoint saved after 1780 images
# Checkpoint saved after 1790 images
# Checkpoint saved after 1800 images
# Checkpoint saved after 1810 images
# Checkpoint saved after 1820 images
# Checkpoint saved after 1830 images
# Checkpoint saved after 1840 images
# Checkpoint saved after 1850 images
# Checkpoint saved after 1860 images
# Checkpoint saved after 1870 images
# Checkpoint saved after 1880 images
# Checkpoint saved after 1890 images
# Checkpoint saved after 1900 images
# Checkpoint saved after 1910 images
# Checkpoint saved after 1920 images
# Checkpoint saved after 1930 images
# Checkpoint saved after 1940 images
# Checkpoint saved after 1950 images
# Checkpoint saved after 1960 images
# Checkpoint saved after 1970 images
# Checkpoint saved after 1980 images
# Checkpoint saved after 1990 images
# Checkpoint saved after 2000 images
# Checkpoint saved after 2010 images
# Checkpoint saved after 2020 images
# Checkpoint saved after 2030 images
# Checkpoint saved after 2040 images
# Checkpoint saved after 2050 images
# Checkpoint saved after 2060 images
# Checkpoint saved after 2070 images
# Checkpoint saved after 2080 images
# Checkpoint saved after 2090 images
# Checkpoint saved after 2100 images
# Checkpoint saved after 2110 images
# Checkpoint saved after 2120 images
# Checkpoint saved after 2130 images
# Checkpoint saved after 2140 images
# Checkpoint saved after 2150 images
# Checkpoint saved after 2160 images
# Checkpoint saved after 2170 images
# Checkpoint saved after 2180 images
# Checkpoint saved after 2190 images
# Checkpoint saved after 2200 images
# Checkpoint saved after 2210 images
# Checkpoint saved after 2220 images
# Checkpoint saved after 2230 images
# Checkpoint saved after 2240 images
# Checkpoint saved after 2250 images
# Checkpoint saved after 2260 images
# Checkpoint saved after 2270 images
# Checkpoint saved after 2280 images
# Checkpoint saved after 2290 images
# Checkpoint saved after 2300 images
# Checkpoint saved after 2310 images
# Checkpoint saved after 2320 images
# Checkpoint saved after 2330 images
# Checkpoint saved after 2340 images
# Checkpoint saved after 2350 images
# Checkpoint saved after 2360 images
# Checkpoint saved after 2370 images
# Checkpoint saved after 2380 images
# Checkpoint saved after 2390 images
# Checkpoint saved after 2400 images
# Checkpoint saved after 2410 images
# Checkpoint saved after 2420 images
# Checkpoint saved after 2430 images
# Checkpoint saved after 2440 images
# Checkpoint saved after 2450 images
# Checkpoint saved after 2460 images
# Checkpoint saved after 2470 images
# Checkpoint saved after 2480 images
# Checkpoint saved after 2490 images
# Checkpoint saved after 2500 images
# Checkpoint saved after 2510 images
# Checkpoint saved after 2520 images
# Checkpoint saved after 2530 images
# Checkpoint saved after 2540 images
# Checkpoint saved after 2550 images
# Checkpoint saved after 2560 images
# Checkpoint saved after 2570 images
# Checkpoint saved after 2580 images
# Checkpoint saved after 2590 images
# Checkpoint saved after 2600 images
# Checkpoint saved after 2610 images
# Checkpoint saved after 2620 images
# Checkpoint saved after 2630 images
# Checkpoint saved after 2640 images
# Checkpoint saved after 2650 images
# Checkpoint saved after 2660 images
# Checkpoint saved after 2670 images
# Checkpoint saved after 2680 images
# Checkpoint saved after 2690 images
# Checkpoint saved after 2700 images
# Checkpoint saved after 2710 images
# Checkpoint saved after 2720 images
# Checkpoint saved after 2730 images
# Checkpoint saved after 2740 images
# Checkpoint saved after 2750 images
# Checkpoint saved after 2760 images
# Checkpoint saved after 2770 images
# Checkpoint saved after 2780 images
# Checkpoint saved after 2790 images
# Checkpoint saved after 2800 images
# Checkpoint saved after 2810 images
# Checkpoint saved after 2820 images
# Checkpoint saved after 2830 images
# Checkpoint saved after 2840 images
# Checkpoint saved after 2850 images
# Checkpoint saved after 2860 images
# Checkpoint saved after 2870 images
# Checkpoint saved after 2880 images
# Checkpoint saved after 2890 images
# Checkpoint saved after 2900 images
# Checkpoint saved after 2910 images
# Checkpoint saved after 2920 images
# Checkpoint saved after 2930 images
# Checkpoint saved after 2940 images
# Checkpoint saved after 2950 images
# Checkpoint saved after 2960 images
# Checkpoint saved after 2970 images
# Checkpoint saved after 2980 images
# Checkpoint saved after 2990 images
# Checkpoint saved after 3000 images
# Checkpoint saved after 3010 images
# Checkpoint saved after 3020 images
# Checkpoint saved after 3030 images
# Checkpoint saved after 3040 images
# Checkpoint saved after 3050 images
# Checkpoint saved after 3060 images
# Checkpoint saved after 3070 images
# Checkpoint saved after 3080 images
# Checkpoint saved after 3090 images
# Checkpoint saved after 3100 images
# Checkpoint saved after 3110 images
# Checkpoint saved after 3120 images
# Checkpoint saved after 3130 images
# Checkpoint saved after 3140 images
# Checkpoint saved after 3150 images
# Checkpoint saved after 3160 images
# Checkpoint saved after 3170 images
# Checkpoint saved after 3180 images
# Checkpoint saved after 3190 images
# Checkpoint saved after 3200 images
# Checkpoint saved after 3210 images
# Checkpoint saved after 3220 images
# Checkpoint saved after 3230 images
# Checkpoint saved after 3240 images
# Checkpoint saved after 3250 images
# Checkpoint saved after 3260 images
# Checkpoint saved after 3270 images
# Checkpoint saved after 3280 images
# Checkpoint saved after 3290 images
# Checkpoint saved after 3300 images
# Checkpoint saved after 3310 images
# Checkpoint saved after 3320 images
# Checkpoint saved after 3330 images
# Checkpoint saved after 3340 images
# Checkpoint saved after 3350 images
# Checkpoint saved after 3360 images
# Checkpoint saved after 3370 images
# Checkpoint saved after 3380 images
# Checkpoint saved after 3390 images
# Checkpoint saved after 3400 images
# Checkpoint saved after 3410 images
# Checkpoint saved after 3420 images
# Checkpoint saved after 3430 images
# Checkpoint saved after 3440 images
# Checkpoint saved after 3450 images
# Checkpoint saved after 3460 images
# Checkpoint saved after 3470 images
# Checkpoint saved after 3480 images
# Checkpoint saved after 3490 images
# Checkpoint saved after 3500 images
# Checkpoint saved after 3510 images
# Checkpoint saved after 3520 images
# Checkpoint saved after 3530 images
# Checkpoint saved after 3540 images
# Checkpoint saved after 3550 images
# Checkpoint saved after 3560 images
# Checkpoint saved after 3570 images
# Checkpoint saved after 3580 images
# Checkpoint saved after 3590 images
# Checkpoint saved after 3600 images
# Checkpoint saved after 3610 images
# Checkpoint saved after 3620 images
# Checkpoint saved after 3630 images
# Checkpoint saved after 3640 images
# Checkpoint saved after 3650 images
# Checkpoint saved after 3660 images
# Checkpoint saved after 3670 images
# Checkpoint saved after 3680 images
# Checkpoint saved after 3690 images
# Checkpoint saved after 3700 images
# Checkpoint saved after 3710 images
# Checkpoint saved after 3720 images
# Checkpoint saved after 3730 images
# Checkpoint saved after 3740 images
# Checkpoint saved after 3750 images
# Checkpoint saved after 3760 images
# Checkpoint saved after 3770 images
# Checkpoint saved after 3780 images
# Checkpoint saved after 3790 images
# Checkpoint saved after 3800 images
# Checkpoint saved after 3810 images
# Checkpoint saved after 3820 images
# Checkpoint saved after 3830 images
# Checkpoint saved after 3840 images
# Checkpoint saved after 3850 images
# Checkpoint saved after 3860 images
# Checkpoint saved after 3870 images
# Checkpoint saved after 3880 images
# Checkpoint saved after 3890 images
# Checkpoint saved after 3900 images
# Checkpoint saved after 3910 images
# Checkpoint saved after 3920 images
# Checkpoint saved after 3930 images
# Checkpoint saved after 3940 images
# Checkpoint saved after 3950 images
# Checkpoint saved after 3960 images
# Checkpoint saved after 3970 images
# Checkpoint saved after 3980 images
# Checkpoint saved after 3990 images
# Checkpoint saved after 4000 images
# Checkpoint saved after 4010 images
# Checkpoint saved after 4020 images
# Checkpoint saved after 4030 images
# Checkpoint saved after 4040 images
# Checkpoint saved after 4050 images
# Checkpoint saved after 4060 images
# Checkpoint saved after 4070 images
# Checkpoint saved after 4080 images
# Checkpoint saved after 4090 images
# Checkpoint saved after 4100 images
# Checkpoint saved after 4110 images
# Checkpoint saved after 4120 images
# Checkpoint saved after 4130 images
# Checkpoint saved after 4140 images
# Checkpoint saved after 4150 images
# Checkpoint saved after 4160 images
# Checkpoint saved after 4170 images
# Checkpoint saved after 4180 images
# Checkpoint saved after 4190 images
# Checkpoint saved after 4200 images
# Checkpoint saved after 4210 images
# Checkpoint saved after 4220 images
# Checkpoint saved after 4230 images
# Checkpoint saved after 4240 images
# Checkpoint saved after 4250 images
# Checkpoint saved after 4260 images
# Checkpoint saved after 4270 images
# Checkpoint saved after 4280 images
# Checkpoint saved after 4290 images
# Checkpoint saved after 4300 images
# Checkpoint saved after 4310 images
# Checkpoint saved after 4320 images
# Checkpoint saved after 4330 images
# Checkpoint saved after 4340 images
# Checkpoint saved after 4350 images
# Checkpoint saved after 4360 images
# Checkpoint saved after 4370 images
# Checkpoint saved after 4380 images
# Checkpoint saved after 4390 images
# Checkpoint saved after 4400 images
# Checkpoint saved after 4410 images
# Checkpoint saved after 4420 images
# Checkpoint saved after 4430 images
# Checkpoint saved after 4440 images
# Checkpoint saved after 4450 images
# Checkpoint saved after 4460 images
# Checkpoint saved after 4470 images
# Checkpoint saved after 4480 images
# Checkpoint saved after 4490 images
# Checkpoint saved after 4500 images
# Checkpoint saved after 4510 images
# Checkpoint saved after 4520 images
# Checkpoint saved after 4530 images
# Checkpoint saved after 4540 images
# Checkpoint saved after 4550 images
# Checkpoint saved after 4560 images
# Checkpoint saved after 4570 images
# Checkpoint saved after 4580 images
# Checkpoint saved after 4590 images
# Checkpoint saved after 4600 images
# Checkpoint saved after 4610 images
# Checkpoint saved after 4620 images
# Checkpoint saved after 4630 images
# Checkpoint saved after 4640 images
# Checkpoint saved after 4650 images
# Checkpoint saved after 4660 images
# Checkpoint saved after 4670 images
# Checkpoint saved after 4680 images
# Checkpoint saved after 4690 images
# Checkpoint saved after 4700 images
# Checkpoint saved after 4710 images
# Checkpoint saved after 4720 images
# Checkpoint saved after 4730 images
# Checkpoint saved after 4740 images
# Checkpoint saved after 4750 images
# Checkpoint saved after 4760 images
# Checkpoint saved after 4770 images
# Checkpoint saved after 4780 images
# Checkpoint saved after 4790 images
# Checkpoint saved after 4800 images
# Checkpoint saved after 4810 images
# Checkpoint saved after 4820 images
# Checkpoint saved after 4830 images
# Checkpoint saved after 4840 images
# Checkpoint saved after 4850 images
# Checkpoint saved after 4850 images
# Checkpoint saved after 4860 images
# Checkpoint saved after 4870 images
# Checkpoint saved after 4880 images
# Checkpoint saved after 4890 images
# Checkpoint saved after 4900 images
# Checkpoint saved after 4910 images
# Checkpoint saved after 4920 images
# Checkpoint saved after 4930 images
# Checkpoint saved after 4940 images
# Checkpoint saved after 4950 images
# Checkpoint saved after 4960 images
# Checkpoint saved after 4970 images
# Checkpoint saved after 4980 images
# Checkpoint saved after 4990 images
# Checkpoint saved after 5000 images
# Checkpoint saved after 5010 images
# Checkpoint saved after 5020 images
# Checkpoint saved after 5030 images
# Checkpoint saved after 5040 images
# Checkpoint saved after 5050 images
# Checkpoint saved after 5060 images
# Checkpoint saved after 5070 images
# Checkpoint saved after 5080 images
# Checkpoint saved after 5090 images
# Checkpoint saved after 5100 images
# Checkpoint saved after 5110 images
# Checkpoint saved after 5120 images
# Checkpoint saved after 5130 images
# Checkpoint saved after 5140 images
# Checkpoint saved after 5150 images
# Checkpoint saved after 5160 images
# Checkpoint saved after 5170 images
# Checkpoint saved after 5180 images
# Checkpoint saved after 5190 images
# Checkpoint saved after 5200 images
# Checkpoint saved after 5210 images
# Checkpoint saved after 5220 images
# Checkpoint saved after 5230 images
# Checkpoint saved after 5240 images
# Checkpoint saved after 5250 images
# Checkpoint saved after 5260 images
# Checkpoint saved after 5270 images
# Checkpoint saved after 5280 images
# Checkpoint saved after 5290 images
# Checkpoint saved after 5300 images
# Checkpoint saved after 5310 images
# Checkpoint saved after 5320 images
# Checkpoint saved after 5330 images
# Checkpoint saved after 5340 images
# Checkpoint saved after 5350 images
# Checkpoint saved after 5360 images
# Checkpoint saved after 5370 images
# Checkpoint saved after 5380 images
# Checkpoint saved after 5390 images
# Checkpoint saved after 5400 images
# Checkpoint saved after 5410 images
# Checkpoint saved after 5420 images
# Checkpoint saved after 5430 images
# Checkpoint saved after 5440 images
# Checkpoint saved after 5450 images
# Checkpoint saved after 5460 images
# Checkpoint saved after 5470 images
# Checkpoint saved after 5480 images
# Checkpoint saved after 5490 images
# Checkpoint saved after 5500 images
# Checkpoint saved after 5510 images
# Checkpoint saved after 5520 images
# Checkpoint saved after 5530 images
# Checkpoint saved after 5540 images
# Checkpoint saved after 5550 images
# Checkpoint saved after 5560 images
# Checkpoint saved after 5570 images
# Checkpoint saved after 5580 images
# Checkpoint saved after 5590 images
# Checkpoint saved after 5600 images
# Checkpoint saved after 5610 images
# Checkpoint saved after 5620 images
# Checkpoint saved after 5630 images
# Checkpoint saved after 5640 images
# Checkpoint saved after 5650 images
# Checkpoint saved after 5660 images
# Checkpoint saved after 5670 images
# Checkpoint saved after 5680 images
# Checkpoint saved after 5690 images
# Checkpoint saved after 5700 images
# Checkpoint saved after 5710 images
# Checkpoint saved after 5720 images
# Checkpoint saved after 5730 images
# Checkpoint saved after 5740 images
# Checkpoint saved after 5750 images
# Checkpoint saved after 5760 images
# Checkpoint saved after 5770 images
# Checkpoint saved after 5780 images
# Checkpoint saved after 5790 images
# Checkpoint saved after 5800 images
# Checkpoint saved after 5810 images
# Checkpoint saved after 5820 images
# Checkpoint saved after 5830 images
# Checkpoint saved after 5840 images
# Checkpoint saved after 5850 images
# Checkpoint saved after 5860 images
# Checkpoint saved after 5870 images
# Checkpoint saved after 5880 images
# Checkpoint saved after 5890 images
# Checkpoint saved after 5900 images
# Checkpoint saved after 5910 images
# Checkpoint saved after 5920 images
# Checkpoint saved after 5930 images
# Checkpoint saved after 5940 images
# Checkpoint saved after 5950 images
# Checkpoint saved after 5960 images
# Checkpoint saved after 5970 images
# Checkpoint saved after 5980 images
# Checkpoint saved after 5990 images
# Checkpoint saved after 6000 images
# Checkpoint saved after 6010 images
# Checkpoint saved after 6020 images
# Checkpoint saved after 6030 images
# Checkpoint saved after 6040 images
# Checkpoint saved after 6050 images
# Checkpoint saved after 6060 images
# Checkpoint saved after 6070 images
# Checkpoint saved after 6080 images
# Checkpoint saved after 6090 images
# Checkpoint saved after 6100 images
# Checkpoint saved after 6110 images
# Checkpoint saved after 6120 images
# Checkpoint saved after 6130 images
# Checkpoint saved after 6140 images
# Checkpoint saved after 6150 images
# Checkpoint saved after 6160 images
# Checkpoint saved after 6170 images
# Checkpoint saved after 6180 images
# Checkpoint saved after 6190 images
# Checkpoint saved after 6200 images
# Checkpoint saved after 6210 images
# Checkpoint saved after 6220 images
# Checkpoint saved after 6230 images
# Checkpoint saved after 6240 images
# Checkpoint saved after 6250 images
# Checkpoint saved after 6260 images
# Checkpoint saved after 6270 images
# Checkpoint saved after 6280 images
# Checkpoint saved after 6290 images
# Checkpoint saved after 6300 images
# Checkpoint saved after 6310 images
# Checkpoint saved after 6320 images
# Checkpoint saved after 6330 images
# Checkpoint saved after 6340 images
# Checkpoint saved after 6350 images
# Checkpoint saved after 6360 images
# Checkpoint saved after 6370 images
# Checkpoint saved after 6380 images
# Checkpoint saved after 6390 images
# Checkpoint saved after 6400 images
# Checkpoint saved after 6410 images
# Checkpoint saved after 6420 images
# Checkpoint saved after 6430 images
# Checkpoint saved after 6440 images
# Checkpoint saved after 6450 images
# Checkpoint saved after 6460 images
# Checkpoint saved after 6470 images
# Checkpoint saved after 6480 images
# Checkpoint saved after 6490 images
# Checkpoint saved after 6500 images
# Checkpoint saved after 6510 images
# Checkpoint saved after 6520 images
# Checkpoint saved after 6530 images
# Checkpoint saved after 6540 images
# Checkpoint saved after 6550 images
# Checkpoint saved after 6560 images
# Checkpoint saved after 6570 images
# Checkpoint saved after 6580 images
# Checkpoint saved after 6590 images
# Checkpoint saved after 6600 images
# Checkpoint saved after 6610 images
# Checkpoint saved after 6620 images
# Checkpoint saved after 6630 images
# Checkpoint saved after 6640 images
# Checkpoint saved after 6650 images
# Checkpoint saved after 6660 images
# Checkpoint saved after 6670 images
# Checkpoint saved after 6680 images
# Checkpoint saved after 6690 images
# Checkpoint saved after 6700 images
# Checkpoint saved after 6710 images
# Checkpoint saved after 6720 images
# Checkpoint saved after 6730 images
# Checkpoint saved after 6740 images
# Checkpoint saved after 6750 images
# Checkpoint saved after 6760 images
# Checkpoint saved after 6770 images
# Checkpoint saved after 6780 images
# Checkpoint saved after 6790 images
# Checkpoint saved after 6800 images
# Checkpoint saved after 6810 images
# Checkpoint saved after 6820 images
# Checkpoint saved after 6830 images
# Checkpoint saved after 6840 images
# Checkpoint saved after 6850 images
# Checkpoint saved after 6860 images
# Checkpoint saved after 6870 images
# Checkpoint saved after 6880 images
# Checkpoint saved after 6890 images
# Checkpoint saved after 6900 images
# Checkpoint saved after 6910 images
# Checkpoint saved after 6920 images
# Checkpoint saved after 6930 images
# Checkpoint saved after 6940 images
# Checkpoint saved after 6950 images
# Checkpoint saved after 6960 images
# Checkpoint saved after 6970 images
# Checkpoint saved after 6980 images
# Checkpoint saved after 6990 images
# Checkpoint saved after 7000 images
# Checkpoint saved after 7010 images
# Checkpoint saved after 7020 images
# Checkpoint saved after 7030 images
# Checkpoint saved after 7040 images
# Checkpoint saved after 7050 images
# Checkpoint saved after 7060 images
# Checkpoint saved after 7070 images
# Checkpoint saved after 7080 images
# Checkpoint saved after 7090 images
# Checkpoint saved after 7100 images
# Checkpoint saved after 7110 images
# Checkpoint saved after 7120 images
# Checkpoint saved after 7130 images
# Checkpoint saved after 7140 images
# Checkpoint saved after 7150 images
# Checkpoint saved after 7160 images
# Checkpoint saved after 7170 images
# Checkpoint saved after 7180 images
# Checkpoint saved after 7190 images
# Checkpoint saved after 7200 images
# Checkpoint saved after 7210 images
# Checkpoint saved after 7220 images
# Checkpoint saved after 7230 images
# Checkpoint saved after 7240 images
# Checkpoint saved after 7250 images
# Checkpoint saved after 7260 images
# Checkpoint saved after 7270 images
# Checkpoint saved after 7280 images
# Checkpoint saved after 7290 images
# Checkpoint saved after 7300 images
# Checkpoint saved after 7310 images
# Checkpoint saved after 7320 images
# Checkpoint saved after 7330 images
# Checkpoint saved after 7340 images
# Checkpoint saved after 7350 images
# Checkpoint saved after 7360 images
# Checkpoint saved after 7370 images
# Checkpoint saved after 7380 images
# Checkpoint saved after 7390 images
# Checkpoint saved after 7400 images
# Checkpoint saved after 7410 images
# Checkpoint saved after 7420 images
# Checkpoint saved after 7430 images
# Checkpoint saved after 7440 images
# Checkpoint saved after 7450 images
# Checkpoint saved after 7460 images
# Checkpoint saved after 7470 images
# Checkpoint saved after 7480 images
# Checkpoint saved after 7490 images
# Checkpoint saved after 7500 images
# Checkpoint saved after 7510 images
# Checkpoint saved after 7520 images
# Checkpoint saved after 7530 images
# Checkpoint saved after 7540 images
# Checkpoint saved after 7550 images
# Checkpoint saved after 7560 images
# Checkpoint saved after 7570 images
# Checkpoint saved after 7580 images
# Checkpoint saved after 7590 images
# Checkpoint saved after 7600 images
# Checkpoint saved after 7610 images
# Checkpoint saved after 7620 images
# Checkpoint saved after 7630 images
# Checkpoint saved after 7640 images
# Checkpoint saved after 7650 images
# Checkpoint saved after 7660 images
# Checkpoint saved after 7670 images
# Checkpoint saved after 7680 images
# Checkpoint saved after 7690 images
# Checkpoint saved after 7700 images
# Checkpoint saved after 7710 images
# Checkpoint saved after 7720 images
# Checkpoint saved after 7730 images
# Checkpoint saved after 7740 images
# Checkpoint saved after 7750 images
# Checkpoint saved after 7760 images
# Checkpoint saved after 7770 images
# Checkpoint saved after 7780 images
# Checkpoint saved after 7790 images
# Checkpoint saved after 7800 images
# Checkpoint saved after 7810 images
# Checkpoint saved after 7820 images
# Checkpoint saved after 7830 images
# Checkpoint saved after 7840 images
# Checkpoint saved after 7850 images
# Checkpoint saved after 7860 images
# Checkpoint saved after 7870 images
# Checkpoint saved after 7880 images
# Checkpoint saved after 7890 images
# Checkpoint saved after 7900 images
# Checkpoint saved after 7910 images
# Checkpoint saved after 7920 images
# Checkpoint saved after 7930 images
# Checkpoint saved after 7940 images
# Checkpoint saved after 7950 images
# Checkpoint saved after 7960 images
# Checkpoint saved after 7970 images
# Checkpoint saved after 7980 images
# Checkpoint saved after 7990 images
# Checkpoint saved after 8000 images
# Checkpoint saved after 8010 images
# Checkpoint saved after 8020 images
# Checkpoint saved after 8030 images
# Checkpoint saved after 8040 images
# Checkpoint saved after 8050 images
# Checkpoint saved after 8060 images
# Checkpoint saved after 8070 images
# Checkpoint saved after 8080 images
# Checkpoint saved after 8090 images
# Checkpoint saved after 8100 images
# Checkpoint saved after 8110 images
# Checkpoint saved after 8120 images
# Checkpoint saved after 8130 images
# Checkpoint saved after 8140 images
# Checkpoint saved after 8150 images
# Checkpoint saved after 8160 images
# Checkpoint saved after 8170 images
# Checkpoint saved after 8180 images
# Checkpoint saved after 8190 images
# Checkpoint saved after 8200 images
# Checkpoint saved after 8210 images
# Checkpoint saved after 8220 images
# Checkpoint saved after 8230 images
# Checkpoint saved after 8240 images
# Checkpoint saved after 8250 images
# Checkpoint saved after 8260 images
# Checkpoint saved after 8270 images
# Checkpoint saved after 8280 images
# Checkpoint saved after 8290 images
# Checkpoint saved after 8300 images
# Checkpoint saved after 8310 images
# Checkpoint saved after 8320 images
# Checkpoint saved after 8330 images
# Checkpoint saved after 8340 images
# Checkpoint saved after 8350 images
# Checkpoint saved after 8360 images
# Checkpoint saved after 8370 images
# Checkpoint saved after 8380 images
# Checkpoint saved after 8390 images
# Checkpoint saved after 8400 images
# Checkpoint saved after 8410 images
# Checkpoint saved after 8420 images
# Checkpoint saved after 8430 images
# Checkpoint saved after 8440 images
# Checkpoint saved after 8450 images
# Checkpoint saved after 8460 images
# Checkpoint saved after 8470 images
# Checkpoint saved after 8480 images
# Checkpoint saved after 8490 images
# Checkpoint saved after 8500 images
# Checkpoint saved after 8510 images
# Checkpoint saved after 8520 images
# Checkpoint saved after 8530 images
# Checkpoint saved after 8540 images
# Checkpoint saved after 8550 images
# Checkpoint saved after 8560 images
# Checkpoint saved after 8570 images
# Checkpoint saved after 8580 images
# Checkpoint saved after 8590 images
# Checkpoint saved after 8600 images
# Checkpoint saved after 8610 images
# Checkpoint saved after 8620 images
# Checkpoint saved after 8630 images
# Checkpoint saved after 8640 images
# Checkpoint saved after 8650 images
# Checkpoint saved after 8660 images
# Checkpoint saved after 8670 images
# Checkpoint saved after 8680 images
# Checkpoint saved after 8690 images
# Checkpoint saved after 8700 images
# Checkpoint saved after 8710 images
# Checkpoint saved after 8720 images
# Checkpoint saved after 8730 images
# Checkpoint saved after 8740 images
# Checkpoint saved after 8750 images
# Checkpoint saved after 8760 images
# Checkpoint saved after 8770 images
# Checkpoint saved after 8780 images
# Checkpoint saved after 8790 images
# Checkpoint saved after 8800 images
# Checkpoint saved after 8810 images
# Checkpoint saved after 8820 images
# Checkpoint saved after 8830 images
# Checkpoint saved after 8840 images
# Checkpoint saved after 8850 images
# Checkpoint saved after 8860 images
# Checkpoint saved after 8870 images
# Checkpoint saved after 8880 images
# Checkpoint saved after 8890 images
# Checkpoint saved after 8900 images
# Checkpoint saved after 8910 images
# Checkpoint saved after 8920 images
# Checkpoint saved after 8930 images
# Checkpoint saved after 8940 images
# Checkpoint saved after 8950 images
# Checkpoint saved after 8960 images
# Checkpoint saved after 8970 images
# Checkpoint saved after 8980 images
# Checkpoint saved after 8990 images
# Checkpoint saved after 9000 images
# Checkpoint saved after 9010 images
# Checkpoint saved after 9020 images
# Checkpoint saved after 9030 images
# Checkpoint saved after 9040 images
# Checkpoint saved after 9050 images
# Checkpoint saved after 9060 images
# Checkpoint saved after 9070 images
# Checkpoint saved after 9080 images
# Checkpoint saved after 9090 images
# Checkpoint saved after 9100 images
# Checkpoint saved after 9110 images
# Checkpoint saved after 9120 images
# Checkpoint saved after 9130 images
# Checkpoint saved after 9140 images
# Checkpoint saved after 9150 images
# Checkpoint saved after 9160 images
# Checkpoint saved after 9170 images
# Checkpoint saved after 9180 images
# Checkpoint saved after 9190 images
# Checkpoint saved after 9200 images
# Checkpoint saved after 9210 images
# Checkpoint saved after 9220 images
# Checkpoint saved after 9230 images
# Checkpoint saved after 9240 images
# Checkpoint saved after 9250 images
# Checkpoint saved after 9260 images
# Checkpoint saved after 9270 images
# Checkpoint saved after 9280 images
# Checkpoint saved after 9290 images
# Checkpoint saved after 9300 images
# Checkpoint saved after 9310 images
# Checkpoint saved after 9320 images
# Checkpoint saved after 9330 images
# Checkpoint saved after 9340 images
# Checkpoint saved after 9350 images
# Checkpoint saved after 9360 images
# Checkpoint saved after 9370 images
# Checkpoint saved after 9380 images
# Checkpoint saved after 9390 images
# Checkpoint saved after 9400 images
# Checkpoint saved after 9410 images
# Checkpoint saved after 9420 images
# Checkpoint saved after 9430 images
# Checkpoint saved after 9440 images
# Checkpoint saved after 9450 images
# Checkpoint saved after 9460 images
# Checkpoint saved after 9470 images
# Checkpoint saved after 9480 images
# Checkpoint saved after 9490 images
# Checkpoint saved after 9500 images
# Checkpoint saved after 9510 images
# Checkpoint saved after 9520 images
# Checkpoint saved after 9530 images
# Checkpoint saved after 9540 images
# Checkpoint saved after 9550 images
# Checkpoint saved after 9560 images
# Checkpoint saved after 9570 images
# Checkpoint saved after 9580 images
# Checkpoint saved after 9590 images
# Checkpoint saved after 9600 images
# Checkpoint saved after 9610 images
# Checkpoint saved after 9620 images
# Checkpoint saved after 9630 images
# Checkpoint saved after 9640 images
# Checkpoint saved after 9650 images
# Checkpoint saved after 9660 images
# Checkpoint saved after 9670 images
# Checkpoint saved after 9680 images
# Checkpoint saved after 9690 images
# Checkpoint saved after 9700 images
# Checkpoint saved after 9710 images
# Checkpoint saved after 9720 images
# Checkpoint saved after 9730 images
# Checkpoint saved after 9740 images
# Checkpoint saved after 9750 images
# Checkpoint saved after 9760 images
# Checkpoint saved after 9770 images
# Checkpoint saved after 9780 images
# Checkpoint saved after 9790 images
# Checkpoint saved after 9800 images
# Checkpoint saved after 9810 images
# Checkpoint saved after 9820 images
# Checkpoint saved after 9830 images
# Checkpoint saved after 9840 images
# Checkpoint saved after 9850 images
# Checkpoint saved after 9860 images
# Checkpoint saved after 9870 images
# Checkpoint saved after 9880 images
# Checkpoint saved after 9890 images
# Checkpoint saved after 9900 images
# Checkpoint saved after 9910 images
# Checkpoint saved after 9920 images
# Checkpoint saved after 9930 images
# Checkpoint saved after 9940 images
# Checkpoint saved after 9950 images
# Checkpoint saved after 9960 images
# Checkpoint saved after 9970 images
# Checkpoint saved after 9980 images
# Checkpoint saved after 9990 images
# Checkpoint saved after 10000 images
# Checkpoint saved after 10010 images
# Checkpoint saved after 10020 images
# Checkpoint saved after 10030 images
# Checkpoint saved after 10040 images
# Checkpoint saved after 10050 images
# Checkpoint saved after 10060 images
# Checkpoint saved after 10070 images
# Checkpoint saved after 10080 images
# Checkpoint saved after 10090 images
# Checkpoint saved after 10100 images
# Checkpoint saved after 10110 images
# Checkpoint saved after 10120 images
# Checkpoint saved after 10130 images
# Checkpoint saved after 10140 images
# Checkpoint saved after 10150 images
# Checkpoint saved after 10160 images
# Checkpoint saved after 10170 images
# Checkpoint saved after 10180 images
# Checkpoint saved after 10190 images
# Checkpoint saved after 10200 images
# Checkpoint saved after 10210 images
# Checkpoint saved after 10220 images
# Checkpoint saved after 10230 images
# Checkpoint saved after 10240 images
# Checkpoint saved after 10250 images
# Checkpoint saved after 10260 images
# Checkpoint saved after 10270 images
# Checkpoint saved after 10280 images
# Checkpoint saved after 10290 images
# Checkpoint saved after 10300 images
# Checkpoint saved after 10310 images
# Checkpoint saved after 10320 images
# Checkpoint saved after 10330 images
# Checkpoint saved after 10340 images
# Checkpoint saved after 10350 images
# Checkpoint saved after 10360 images
# Checkpoint saved after 10370 images
# Checkpoint saved after 10380 images
# Checkpoint saved after 10390 images
# Checkpoint saved after 10400 images
# Checkpoint saved after 10410 images
# Checkpoint saved after 10420 images
# Checkpoint saved after 10430 images
# Checkpoint saved after 10440 images
# Checkpoint saved after 10450 images
# Checkpoint saved after 10460 images
# Checkpoint saved after 10470 images
# Checkpoint saved after 10480 images
# Checkpoint saved after 10490 images
# Checkpoint saved after 10500 images
# Checkpoint saved after 10510 images
# Checkpoint saved after 10520 images
# Checkpoint saved after 10530 images
# Checkpoint saved after 10540 images
# Checkpoint saved after 10550 images
# Checkpoint saved after 10560 images
# Checkpoint saved after 10570 images
# Checkpoint saved after 10580 images
# Checkpoint saved after 10590 images
# Checkpoint saved after 10600 images
# Checkpoint saved after 10610 images
# Checkpoint saved after 10620 images
# Checkpoint saved after 10630 images
# Checkpoint saved after 10640 images
# Checkpoint saved after 10650 images
# Checkpoint saved after 10660 images
# Checkpoint saved after 10670 images
# Checkpoint saved after 10680 images
# Checkpoint saved after 10690 images
# Checkpoint saved after 10700 images
# Checkpoint saved after 10710 images
# Checkpoint saved after 10720 images
# Checkpoint saved after 10730 images
# Checkpoint saved after 10740 images
# Checkpoint saved after 10750 images
# Checkpoint saved after 10760 images
# Checkpoint saved after 10770 images
# Checkpoint saved after 10780 images
# Checkpoint saved after 10790 images
# Checkpoint saved after 10800 images
# Checkpoint saved after 10810 images
# Checkpoint saved after 10820 images
# Checkpoint saved after 10830 images
# Checkpoint saved after 10840 images
# Checkpoint saved after 10850 images
# Checkpoint saved after 10860 images
# Checkpoint saved after 10870 images
# Checkpoint saved after 10880 images
# Checkpoint saved after 10890 images
# Checkpoint saved after 10900 images
# Checkpoint saved after 10910 images
# Checkpoint saved after 10920 images
# Checkpoint saved after 10930 images
# Checkpoint saved after 10940 images
# Checkpoint saved after 10950 images
# Checkpoint saved after 10960 images
# Checkpoint saved after 10970 images
# Checkpoint saved after 10980 images
# Checkpoint saved after 10990 images
# Checkpoint saved after 11000 images
# Checkpoint saved after 11010 images
# Checkpoint saved after 11020 images
# Checkpoint saved after 11030 images
# Checkpoint saved after 11040 images
# Checkpoint saved after 11050 images
# Checkpoint saved after 11060 images
# Checkpoint saved after 11070 images
# Checkpoint saved after 11080 images
# Checkpoint saved after 11090 images
# Checkpoint saved after 11100 images
# Checkpoint saved after 11110 images
# Checkpoint saved after 11120 images
# Checkpoint saved after 11130 images
# Checkpoint saved after 11140 images
# Checkpoint saved after 11150 images
# Checkpoint saved after 11160 images
# Checkpoint saved after 11170 images
# Checkpoint saved after 11180 images
# Checkpoint saved after 11190 images
# Checkpoint saved after 11200 images
# Checkpoint saved after 11210 images
# Checkpoint saved after 11220 images
# Checkpoint saved after 11230 images
# Checkpoint saved after 11240 images
# Checkpoint saved after 11250 images
# Checkpoint saved after 11260 images
# Checkpoint saved after 11270 images
# Checkpoint saved after 11280 images
# Checkpoint saved after 11290 images
# Checkpoint saved after 11300 images
# Checkpoint saved after 11310 images
# Checkpoint saved after 11320 images
# Checkpoint saved after 11330 images
# Checkpoint saved after 11340 images
# Checkpoint saved after 11350 images
# Checkpoint saved after 11360 images
# Checkpoint saved after 11370 images
# Checkpoint saved after 11380 images
# Checkpoint saved after 11390 images
# Checkpoint saved after 11400 images
# Checkpoint saved after 11410 images
# Checkpoint saved after 11420 images
# Checkpoint saved after 11430 images
# Checkpoint saved after 11440 images
# Checkpoint saved after 11450 images
# Checkpoint saved after 11460 images
# Checkpoint saved after 11470 images
# Checkpoint saved after 11480 images
# Checkpoint saved after 11490 images
# Checkpoint saved after 11500 images
# Checkpoint saved after 11510 images
# Checkpoint saved after 11520 images
# Checkpoint saved after 11530 images
# Checkpoint saved after 11540 images
# Checkpoint saved after 11550 images
# Checkpoint saved after 11560 images
# Checkpoint saved after 11570 images
# Checkpoint saved after 11580 images
# Checkpoint saved after 11590 images
# Checkpoint saved after 11600 images
# Checkpoint saved after 11610 images
# Checkpoint saved after 11620 images
# Checkpoint saved after 11630 images
# Checkpoint saved after 11640 images
# Checkpoint saved after 11650 images
# Checkpoint saved after 11660 images
# Checkpoint saved after 11670 images
# Checkpoint saved after 11680 images
# Final embeddings saved
