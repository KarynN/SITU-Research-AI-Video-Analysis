# %%
# !pip install -q -U google-generativeai

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
# Or use `os.getenv('GOOGLE_API_KEY')` to fetch an environment variable.
GOOGLE_API_KEY='key'#userdata.get('GOOGLE_API_KEY')

genai.configure(api_key=GOOGLE_API_KEY)

# %%
import PIL.Image

img = PIL.Image.open('/content/drive/MyDrive/output_frame4.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720>

# %%
model = genai.GenerativeModel('gemini-1.5-flash')

response = model.generate_content(img)

to_markdown(response.text)
# Out:
# > This image shows a large group of people walking in a parking lot.  The crowd is composed of a variety of people, including some in police uniforms.  There are cars parked in the lot, and there is a road leading away from the lot. The image was taken from an overhead view, and the caption includes information about the time and location.  It looks like a peaceful protest or a public event.

# %%
response = model.generate_content(["list all text and numbers in this surveillance image and explain what they mean", img])
to_markdown(response.text)
# Out:
# > - **08 JUN 2020**: This likely refers to the date the image was captured, June 8, 2020.
# > - **18:47:03**: This is the time the image was captured, 6:47:03 PM.
# > - **UTC -4.0**: This indicates the time zone, Coordinated Universal Time (UTC), with a -4 hour offset. This likely corresponds to the Eastern Time Zone.
# > - **30**: This number likely corresponds to a specific camera, sensor, or device ID.
# > - **AUTO**: This indicates the camera's settings are set to automatically adjust based on the environment.
# > - **EO DLL**: This may refer to a specific security protocol, command, or system.
# > - **154W LOW**: This could indicate the camera's location or a specific setting.
# > - **AUTO 50**:  Similar to the previous "AUTO," this might indicate automatic settings or a specific mode for the camera.
# > - **KEYBOARD**: This is a label or indicator, potentially related to a keypad or control panel.
# ...
